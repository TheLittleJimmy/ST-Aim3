# %%
import torch
from torch_geometric.utils import (negative_sampling, remove_self_loops,
                                   add_self_loops)
EPS = 1e-15
MAX_LOGSTD = 10

class InnerProductDecoder(torch.nn.Module):
    r"""The inner product decoder from the `"Variational Graph Auto-Encoders"
    <https://arxiv.org/abs/1611.07308>`_ paper

    .. math::
        \sigma(\mathbf{Z}\mathbf{Z}^{\top})

    where :math:`\mathbf{Z} \in \mathbb{R}^{N \times d}` denotes the latent
    space produced by the encoder."""
    def forward(self, z, edge_index, sigmoid=True):
        r"""Decodes the latent variables :obj:`z` into edge probabilities for
        the given node-pairs :obj:`edge_index`.

        Args:
            z (Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        value = (z[edge_index[0]] * z[edge_index[1]]).sum(dim=1)
        return torch.sigmoid(value) if sigmoid else value


    def forward_all(self, z, sigmoid=True):
        r"""Decodes the latent variables :obj:`z` into a probabilistic dense
        adjacency matrix.

        Args:
            z (Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        adj = torch.matmul(z, z.t())
        return torch.sigmoid(adj) if sigmoid else adj



class GAE(torch.nn.Module):
    r"""The Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper based on user-defined encoder and decoder models.

    Args:
        encoder (Module): The encoder module.
        decoder (Module, optional): The decoder module. If set to :obj:`None`,
            will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """
    def __init__(self, encoder, decoder=None):
        super(GAE, self).__init__()
        self.encoder = encoder
        self.decoder = InnerProductDecoder() if decoder is None else decoder
        GAE.reset_parameters(self)

    def reset_parameters(self):
        reset(self.encoder)
        reset(self.decoder)


    def encode(self, *args, **kwargs):
        r"""Runs the encoder and computes node-wise latent variables."""
        return self.encoder(*args, **kwargs)


    def decode(self, *args, **kwargs):
        r"""Runs the decoder and computes edge probabilities."""
        return self.decoder(*args, **kwargs)


    def recon_loss(self, z, pos_edge_index, neg_edge_index=None):
        r"""Given latent variables :obj:`z`, computes the binary cross
        entropy loss for positive edges :oenbj:`pos_edge_index` and negative
        sampled edges.

        Args:
            z (Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (LongTensor): The positive edges to train against.
            neg_edge_index (LongTensor, optional): The negative edges to train
                against. If not given, uses negative sampling to calculate
                negative edges. (default: :obj:`None`)
        """

        pos_loss = -torch.log(
            self.decoder(z, pos_edge_index, sigmoid=True) + EPS).mean()

        # Do not include self-loops in negative samples
        pos_edge_index, _ = remove_self_loops(pos_edge_index)
        pos_edge_index, _ = add_self_loops(pos_edge_index)
        if neg_edge_index is None:
            neg_edge_index = negative_sampling(pos_edge_index, z.size(0))
        neg_loss = -torch.log(1 -
                              self.decoder(z, neg_edge_index, sigmoid=True) +
                              EPS).mean()

        return pos_loss + neg_loss


    def test(self, z, pos_edge_index, neg_edge_index):
        r"""Given latent variables :obj:`z`, positive edges
        :obj:`pos_edge_index` and negative edges :obj:`neg_edge_index`,
        computes area under the ROC curve (AUC) and average precision (AP)
        scores.

        Args:
            z (Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (LongTensor): The positive edges to evaluate
                against.
            neg_edge_index (LongTensor): The negative edges to evaluate
                against.
        """
        from sklearn.metrics import roc_auc_score, average_precision_score

        pos_y = z.new_ones(pos_edge_index.size(1))
        neg_y = z.new_zeros(neg_edge_index.size(1))
        y = torch.cat([pos_y, neg_y], dim=0)

        pos_pred = self.decoder(z, pos_edge_index, sigmoid=True)
        neg_pred = self.decoder(z, neg_edge_index, sigmoid=True)
        pred = torch.cat([pos_pred, neg_pred], dim=0)
        
        y, pred = y.detach().cpu().numpy(), pred.detach().cpu().numpy()

        return roc_auc_score(y, pred), average_precision_score(y, pred)



class VGAE(GAE):
    r"""The Variational Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper.

    Args:
        encoder (Module): The encoder module to compute :math:`\mu` and
            :math:`\log\sigma^2`.
        decoder (Module, optional): The decoder module. If set to :obj:`None`,
            will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """
    def __init__(self, encoder, decoder=None):
        super(VGAE, self).__init__(encoder, decoder)

    def reparametrize(self, mu, logstd):
        if self.training:
            return mu + torch.randn_like(logstd) * torch.exp(logstd)
        else:
            return mu
    
    def encode(self, *args, **kwargs):
        """"""
        self.__mu__, self.__logstd__ = self.encoder(*args, **kwargs)
        self.__logstd__ = self.__logstd__.clamp(max=MAX_LOGSTD)
        z = self.reparametrize(self.__mu__, self.__logstd__)
        return z

    def kl_loss(self, mu=None, logstd=None):
        r"""Computes the KL loss, either for the passed arguments :obj:`mu`
        and :obj:`logstd`, or based on latent variables from last encoding.

        Args:
            mu (Tensor, optional): The latent space for :math:`\mu`. If set to
                :obj:`None`, uses the last computation of :math:`mu`.
                (default: :obj:`None`)
            logstd (Tensor, optional): The latent space for
                :math:`\log\sigma`.  If set to :obj:`None`, uses the last
                computation of :math:`\log\sigma^2`.(default: :obj:`None`)
        """
        mu = self.__mu__ if mu is None else mu
        logstd = self.__logstd__ if logstd is None else logstd.clamp(
            max=MAX_LOGSTD)
        return -0.5 * torch.mean(
            torch.sum(1 + 2 * logstd - mu**2 - logstd.exp()**2, dim=1))

# %%
import torch
from torch.autograd.grad_mode import F
from torch_geometric.data import Data
from torch_geometric.datasets import Planetoid
import torch_geometric.transforms as T
from torch_geometric.nn import GCNConv
from torch_geometric.utils import train_test_split_edges
from torch_geometric.nn import VGAE

import scipy.sparse as sp
import numpy as np
import networkx as nx

class SimuData():
    """Simulate graph data"""
    def __init__(self, p=0.5, n_node=10, n_graph=30):
        self.n_node = n_node
        self.n_graph = n_graph
        self.p = p

    def simu_adj_wgh(self):
        adj_list = []

        for i in range(self.n_graph):
            ## zero matrix
            A = torch.zeros(self.n_node, self.n_node)

            # first five nodes weights: uniform(0,1)A[:5,:5] = W
            W = torch.rand(5,5)

            ## symmetric
            i, j = torch.triu_indices(5, 5)
            W[i, j] = W.T[i, j]

            A[:5,:5] = W
            adj_list.append(A)  

        return adj_list

    def simu_adj_diag(self):
        adj_list = []

        for i in range(self.n_graph):
            A = torch.eye(self.n_node)
            adj_list.append(A)  

        return adj_list

    def simu_adj_m(self):
        """generating adjacency matrix"""
        adj_wgh = self.simu_adj_wgh()
        #adj_wgh = self.simu_adj_diag()
        adj_m_list =[]
        for _, adj in enumerate(adj_wgh):
            adj[adj>=1-self.p] = 1
            adj[adj<1-self.p] = 0
            for i in range(adj.shape[0]):
                adj[i, i] = 0
            adj_m_list.append(adj)    
        return adj_m_list

    def graph_dataset(self):
        dataset =[]
        simu_adj = self.simu_adj_m()

        for _, adj in enumerate(simu_adj):
            edge_index_temp = sp.coo_matrix(adj)
            indices = np.vstack((edge_index_temp.row, edge_index_temp.col))
            edge_index_A = torch.LongTensor(indices) 
            x = self.get_x_feature()
            data = Data(x=x, edge_index=edge_index_A)
            dataset.append(data)

        return dataset

    def get_x_feature(self):
        x = torch.arange(self.n_node)
        x_onehot = torch.eye(self.n_node)[x,:] 

        return torch.FloatTensor(x_onehot)


class Encoder(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super(Encoder, self).__init__()
        self.conv1 = GCNConv(in_channels, 2 * out_channels, cached=True) 
        self.conv_mu = GCNConv(2 * out_channels, out_channels, cached=True)
        self.conv_logstd = GCNConv(2 * out_channels, out_channels, cached=True)

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index).relu()
        return self.conv_mu(x, edge_index), self.conv_logstd(x, edge_index)


transform = T.Compose([
            T.NormalizeFeatures(),
            T.RandomLinkSplit(num_val=0, num_test=0, is_undirected=True,
                            split_labels=True, add_negative_train_samples=False),])

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.optim import Adam
import torch.nn.functional as F
import numpy as np
import scipy.sparse as sp
from scipy.sparse import csr_matrix


class LoadData():
    """Load graph data"""
    def __init__(self, file_path, samples, n_node=38):
        self.samples = samples
        self.file_path = file_path
        self.nSample = len(samples)
        self.n_node = n_node

    def get_adj_wgh(self):
        """generating adjacency matrix"""
        adj_orig_list =[]
        for sample in self.samples:
            f_name = self.file_path + ".".join([sample])
            adj   = np.asarray(pd.read_csv(f_name, index_col = 0, iterator = False))
            adj_orig_list.append(adj)    

        return adj_orig_list

    def get_adj_label(self):
        adj_m = self.get_adj_m()
        adj_label_list =[]
        
        for _, adj in enumerate(adj_m):
            adj_label = adj + sp.eye(adj.shape[0])
            adj_label = sparse_to_tuple(sp.coo_matrix(adj_label))
            #adj_label = sparse_to_tuple(adj_label)
            adj_label = torch.sparse.FloatTensor(torch.LongTensor(adj_label[0].T), 
                            torch.FloatTensor(adj_label[1]), 
                            torch.Size(adj_label[2]))
            adj_label_list.append(adj_label)
        return adj_label_list

    def get_adj_norm(self):
        adj_m = self.get_adj_m()
        adj_norm_list =[]

        for _, adj in enumerate(adj_m):
            adj_norm = preprocess_graph(adj)
            adj_norm = torch.sparse.FloatTensor(torch.LongTensor(adj_norm[0].T), 
                            torch.FloatTensor(adj_norm[1]), 
                            torch.Size(adj_norm[2]))
            adj_norm_list.append(adj_norm)

        return adj_norm_list

    def get_adj_m(self):
        adj_wgh = self.get_adj_wgh()
        adj_m_list =[]
        for _, adj in enumerate(adj_wgh):
            adj[adj>0] = 1
            for i in range(38):
                adj[i, i] = 0
            for i in range(38):
                for j in range(38):
                    if adj[i, j] == 1:
                        adj[j, i] = 1
            adj_m_list.append(adj)    
        return adj_m_list

    def get_feature(self):
        """generating feature matrix X"""
        adj_wgh = self.get_adj_wgh()
        x_list = []
        for _, adj in enumerate(adj_wgh):
            x_feature  = adj
            x_feature  = csr_matrix(x_feature)
            x_feature  = sparse_to_tuple(x_feature)
            x_feature  = torch.sparse.FloatTensor(torch.LongTensor(x_feature[0].T), 
                            torch.FloatTensor(x_feature[1]), 
                            torch.Size(x_feature[2]))
            x_list.append(x_feature)
        return x_list

    def get_x_feature(self):
        x = torch.arange(self.n_node)
        x_onehot = torch.eye(self.n_node)[x,:] 

        return torch.FloatTensor(x_onehot)   

    def graph_dataset(self):
        dataset =[]
        simu_adj = self.get_adj_m()

        for _, adj in enumerate(simu_adj):
            edge_index_temp = sp.coo_matrix(adj)
            indices = np.vstack((edge_index_temp.row, edge_index_temp.col))
            edge_index_A = torch.LongTensor(indices) 
            x = self.get_x_feature()
            data = Data(x=x, edge_index=edge_index_A)
            dataset.append(data)
        return dataset


def sparse_to_tuple(sparse_mx):
    if not sp.isspmatrix_coo(sparse_mx):
        sparse_mx = sparse_mx.tocoo()
    coords = np.vstack((sparse_mx.row, sparse_mx.col)).transpose()
    values = sparse_mx.data
    shape = sparse_mx.shape
    return coords, values, shape

def preprocess_graph(adj):
    adj = sp.coo_matrix(adj)
    adj_ = adj + sp.eye(adj.shape[0])
    rowsum = np.array(adj_.sum(1))
    degree_mat_inv_sqrt = sp.diags(np.power(rowsum, -0.5).flatten())
    adj_normalized = adj_.dot(degree_mat_inv_sqrt).transpose().dot(degree_mat_inv_sqrt).tocoo()
    
    return sparse_to_tuple(adj_normalized)

from os import walk

def get_filename(mypath):
    f = []
    for (dirpath, dirnames, filenames) in walk(mypath):
        f.extend(filenames)
        break
    return f

# %%
n_node = 10
temp = np.zeros((2, n_node * n_node))
for i in range(n_node):
    for j in range(n_node):
        temp[0, j + n_node*i] = j
for i in range(n_node):
    for j in range(n_node):
        temp[1, j + n_node*i] = i
edge_index = temp

# %%
simu_graph = SimuData(n_graph=30, p=0.8)
dataset = simu_graph.graph_dataset()
n_node = simu_graph.n_node

# %%
out_channels = 2
n_node = 10
num_features = n_node

model = VGAE(Encoder(num_features, out_channels))
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
epochs = 1000

for epoch in range(epochs):
    loss_total = 0
    optimizer.zero_grad()
    
    for i in range(len(dataset)):
        train_data, val_data, test_data = transform(dataset[i])
        z = model.encode(train_data.x, train_data.edge_index)
        loss =10 *model.recon_loss(z, train_data.edge_index)
        loss = loss + (1 /num_features) * model.kl_loss()
        loss_total += loss

    loss_avg = loss_total/len(dataset)
    loss_avg.backward()
    optimizer.step()
    print(str(epoch)+str(loss_avg))
# Out:
# 0tensor(17.4152, grad_fn=<DivBackward0>)
# 1tensor(17.7482, grad_fn=<DivBackward0>)
# 2tensor(16.2003, grad_fn=<DivBackward0>)
# 3tensor(16.4972, grad_fn=<DivBackward0>)
# 4tensor(15.8864, grad_fn=<DivBackward0>)
# 5tensor(17.0410, grad_fn=<DivBackward0>)
# 6tensor(15.2686, grad_fn=<DivBackward0>)
# 7tensor(15.2089, grad_fn=<DivBackward0>)
# 8tensor(16.2794, grad_fn=<DivBackward0>)
# 9tensor(15.5178, grad_fn=<DivBackward0>)
# 10tensor(14.9671, grad_fn=<DivBackward0>)
# 11tensor(15.2167, grad_fn=<DivBackward0>)
# 12tensor(14.6136, grad_fn=<DivBackward0>)
# 13tensor(15.1598, grad_fn=<DivBackward0>)
# 14tensor(14.4127, grad_fn=<DivBackward0>)
# 15tensor(15.0347, grad_fn=<DivBackward0>)
# 16tensor(14.6728, grad_fn=<DivBackward0>)
# 17tensor(13.8851, grad_fn=<DivBackward0>)
# 18tensor(14.3066, grad_fn=<DivBackward0>)
# 19tensor(14.0219, grad_fn=<DivBackward0>)
# 20tensor(13.8912, grad_fn=<DivBackward0>)
# 21tensor(13.6746, grad_fn=<DivBackward0>)
# 22tensor(13.6317, grad_fn=<DivBackward0>)
# 23tensor(13.3424, grad_fn=<DivBackward0>)
# 24tensor(12.9334, grad_fn=<DivBackward0>)
# 25tensor(12.6773, grad_fn=<DivBackward0>)
# 26tensor(13.2993, grad_fn=<DivBackward0>)
# 27tensor(12.4085, grad_fn=<DivBackward0>)
# 28tensor(11.8088, grad_fn=<DivBackward0>)
# 29tensor(11.6844, grad_fn=<DivBackward0>)
# 30tensor(11.6902, grad_fn=<DivBackward0>)
# 31tensor(11.3385, grad_fn=<DivBackward0>)
# 32tensor(12.1960, grad_fn=<DivBackward0>)
# 33tensor(10.7922, grad_fn=<DivBackward0>)
# 34tensor(10.7580, grad_fn=<DivBackward0>)
# 35tensor(10.5720, grad_fn=<DivBackward0>)
# 36tensor(10.5862, grad_fn=<DivBackward0>)
# 37tensor(10.0024, grad_fn=<DivBackward0>)
# 38tensor(10.0218, grad_fn=<DivBackward0>)
# 39tensor(9.9535, grad_fn=<DivBackward0>)
# 40tensor(10.1032, grad_fn=<DivBackward0>)
# 41tensor(10.0280, grad_fn=<DivBackward0>)
# 42tensor(9.6217, grad_fn=<DivBackward0>)
# 43tensor(9.2875, grad_fn=<DivBackward0>)
# 44tensor(9.9250, grad_fn=<DivBackward0>)
# 45tensor(9.4524, grad_fn=<DivBackward0>)
# 46tensor(9.7160, grad_fn=<DivBackward0>)
# 47tensor(9.5238, grad_fn=<DivBackward0>)
# 48tensor(9.2267, grad_fn=<DivBackward0>)
# 49tensor(10.0106, grad_fn=<DivBackward0>)
# 50tensor(9.2546, grad_fn=<DivBackward0>)
# 51tensor(9.7755, grad_fn=<DivBackward0>)
# 52tensor(9.5164, grad_fn=<DivBackward0>)
# 53tensor(9.0834, grad_fn=<DivBackward0>)
# 54tensor(9.0434, grad_fn=<DivBackward0>)
# 55tensor(9.1150, grad_fn=<DivBackward0>)
# 56tensor(9.1796, grad_fn=<DivBackward0>)
# 57tensor(8.9532, grad_fn=<DivBackward0>)
# 58tensor(8.6475, grad_fn=<DivBackward0>)
# 59tensor(9.1704, grad_fn=<DivBackward0>)
# 60tensor(8.5477, grad_fn=<DivBackward0>)
# 61tensor(8.7686, grad_fn=<DivBackward0>)
# 62tensor(8.9720, grad_fn=<DivBackward0>)
# 63tensor(8.2954, grad_fn=<DivBackward0>)
# 64tensor(8.4256, grad_fn=<DivBackward0>)
# 65tensor(8.5965, grad_fn=<DivBackward0>)
# 66tensor(8.8152, grad_fn=<DivBackward0>)
# 67tensor(8.3827, grad_fn=<DivBackward0>)
# 68tensor(8.8308, grad_fn=<DivBackward0>)
# 69tensor(9.5757, grad_fn=<DivBackward0>)
# 70tensor(8.3394, grad_fn=<DivBackward0>)
# 71tensor(8.8368, grad_fn=<DivBackward0>)
# 72tensor(9.1207, grad_fn=<DivBackward0>)
# 73tensor(8.8989, grad_fn=<DivBackward0>)
# 74tensor(8.5374, grad_fn=<DivBackward0>)
# 75tensor(8.8104, grad_fn=<DivBackward0>)
# 76tensor(8.8442, grad_fn=<DivBackward0>)
# 77tensor(8.8739, grad_fn=<DivBackward0>)
# 78tensor(8.5940, grad_fn=<DivBackward0>)
# 79tensor(8.7376, grad_fn=<DivBackward0>)
# 80tensor(8.7357, grad_fn=<DivBackward0>)
# 81tensor(8.4426, grad_fn=<DivBackward0>)
# 82tensor(8.0132, grad_fn=<DivBackward0>)
# 83tensor(8.1118, grad_fn=<DivBackward0>)
# 84tensor(7.7917, grad_fn=<DivBackward0>)
# 85tensor(8.2780, grad_fn=<DivBackward0>)
# 86tensor(8.3646, grad_fn=<DivBackward0>)
# 87tensor(8.2532, grad_fn=<DivBackward0>)
# 88tensor(8.8497, grad_fn=<DivBackward0>)
# 89tensor(8.6706, grad_fn=<DivBackward0>)
# 90tensor(8.5851, grad_fn=<DivBackward0>)
# 91tensor(7.9811, grad_fn=<DivBackward0>)
# 92tensor(8.5408, grad_fn=<DivBackward0>)
# 93tensor(8.3669, grad_fn=<DivBackward0>)
# 94tensor(7.8733, grad_fn=<DivBackward0>)
# 95tensor(8.7100, grad_fn=<DivBackward0>)
# 96tensor(8.7387, grad_fn=<DivBackward0>)
# 97tensor(8.1904, grad_fn=<DivBackward0>)
# 98tensor(8.5142, grad_fn=<DivBackward0>)
# 99tensor(8.2228, grad_fn=<DivBackward0>)
# 100tensor(8.1627, grad_fn=<DivBackward0>)
# 101tensor(8.9360, grad_fn=<DivBackward0>)
# 102tensor(8.2821, grad_fn=<DivBackward0>)
# 103tensor(8.6076, grad_fn=<DivBackward0>)
# 104tensor(8.5841, grad_fn=<DivBackward0>)
# 105tensor(7.6919, grad_fn=<DivBackward0>)
# 106tensor(8.3887, grad_fn=<DivBackward0>)
# 107tensor(8.4119, grad_fn=<DivBackward0>)
# 108tensor(8.4358, grad_fn=<DivBackward0>)
# 109tensor(8.2422, grad_fn=<DivBackward0>)
# 110tensor(8.3118, grad_fn=<DivBackward0>)
# 111tensor(8.4661, grad_fn=<DivBackward0>)
# 112tensor(8.0634, grad_fn=<DivBackward0>)
# 113tensor(9.0190, grad_fn=<DivBackward0>)
# 114tensor(8.3641, grad_fn=<DivBackward0>)
# 115tensor(8.2306, grad_fn=<DivBackward0>)
# 116tensor(8.5001, grad_fn=<DivBackward0>)
# 117tensor(8.2378, grad_fn=<DivBackward0>)
# 118tensor(8.2366, grad_fn=<DivBackward0>)
# 119tensor(8.6022, grad_fn=<DivBackward0>)
# 120tensor(8.1941, grad_fn=<DivBackward0>)
# 121tensor(8.0964, grad_fn=<DivBackward0>)
# 122tensor(8.3862, grad_fn=<DivBackward0>)
# 123tensor(8.4858, grad_fn=<DivBackward0>)
# 124tensor(8.1228, grad_fn=<DivBackward0>)
# 125tensor(8.0508, grad_fn=<DivBackward0>)
# 126tensor(8.5449, grad_fn=<DivBackward0>)
# 127tensor(8.7656, grad_fn=<DivBackward0>)
# 128tensor(8.1744, grad_fn=<DivBackward0>)
# 129tensor(7.9024, grad_fn=<DivBackward0>)
# 130tensor(8.2108, grad_fn=<DivBackward0>)
# 131tensor(7.9235, grad_fn=<DivBackward0>)
# 132tensor(7.9359, grad_fn=<DivBackward0>)
# 133tensor(8.0977, grad_fn=<DivBackward0>)
# 134tensor(8.0942, grad_fn=<DivBackward0>)
# 135tensor(7.8127, grad_fn=<DivBackward0>)
# 136tensor(7.9293, grad_fn=<DivBackward0>)
# 137tensor(8.2025, grad_fn=<DivBackward0>)
# 138tensor(8.2641, grad_fn=<DivBackward0>)
# 139tensor(8.1599, grad_fn=<DivBackward0>)
# 140tensor(8.3231, grad_fn=<DivBackward0>)
# 141tensor(7.6793, grad_fn=<DivBackward0>)
# 142tensor(8.1172, grad_fn=<DivBackward0>)
# 143tensor(8.2073, grad_fn=<DivBackward0>)
# 144tensor(8.3577, grad_fn=<DivBackward0>)
# 145tensor(8.1136, grad_fn=<DivBackward0>)
# 146tensor(7.6827, grad_fn=<DivBackward0>)
# 147tensor(8.1161, grad_fn=<DivBackward0>)
# 148tensor(8.1099, grad_fn=<DivBackward0>)
# 149tensor(7.9976, grad_fn=<DivBackward0>)
# 150tensor(8.3486, grad_fn=<DivBackward0>)
# 151tensor(8.1325, grad_fn=<DivBackward0>)
# 152tensor(8.1485, grad_fn=<DivBackward0>)
# 153tensor(8.3483, grad_fn=<DivBackward0>)
# 154tensor(8.2132, grad_fn=<DivBackward0>)
# 155tensor(7.9806, grad_fn=<DivBackward0>)
# 156tensor(8.0505, grad_fn=<DivBackward0>)
# 157tensor(7.9548, grad_fn=<DivBackward0>)
# 158tensor(8.6679, grad_fn=<DivBackward0>)
# 159tensor(7.7455, grad_fn=<DivBackward0>)
# 160tensor(8.3577, grad_fn=<DivBackward0>)
# 161tensor(8.7115, grad_fn=<DivBackward0>)
# 162tensor(7.9162, grad_fn=<DivBackward0>)
# 163tensor(8.2300, grad_fn=<DivBackward0>)
# 164tensor(7.6288, grad_fn=<DivBackward0>)
# 165tensor(7.7918, grad_fn=<DivBackward0>)
# 166tensor(7.8510, grad_fn=<DivBackward0>)
# 167tensor(8.4267, grad_fn=<DivBackward0>)
# 168tensor(8.0077, grad_fn=<DivBackward0>)
# 169tensor(8.1185, grad_fn=<DivBackward0>)
# 170tensor(8.1092, grad_fn=<DivBackward0>)
# 171tensor(7.9217, grad_fn=<DivBackward0>)
# 172tensor(8.2924, grad_fn=<DivBackward0>)
# 173tensor(7.7253, grad_fn=<DivBackward0>)
# 174tensor(8.0971, grad_fn=<DivBackward0>)
# 175tensor(7.9977, grad_fn=<DivBackward0>)
# 176tensor(8.2848, grad_fn=<DivBackward0>)
# 177tensor(8.4548, grad_fn=<DivBackward0>)
# 178tensor(8.8084, grad_fn=<DivBackward0>)
# 179tensor(8.0724, grad_fn=<DivBackward0>)
# 180tensor(7.9539, grad_fn=<DivBackward0>)
# 181tensor(8.9551, grad_fn=<DivBackward0>)
# 182tensor(7.9833, grad_fn=<DivBackward0>)
# 183tensor(7.8488, grad_fn=<DivBackward0>)
# 184tensor(8.7790, grad_fn=<DivBackward0>)
# 185tensor(7.9628, grad_fn=<DivBackward0>)
# 186tensor(7.9272, grad_fn=<DivBackward0>)
# 187tensor(8.4098, grad_fn=<DivBackward0>)
# 188tensor(8.0725, grad_fn=<DivBackward0>)
# 189tensor(7.5964, grad_fn=<DivBackward0>)
# 190tensor(8.1671, grad_fn=<DivBackward0>)
# 191tensor(8.0721, grad_fn=<DivBackward0>)
# 192tensor(8.5122, grad_fn=<DivBackward0>)
# 193tensor(8.3837, grad_fn=<DivBackward0>)
# 194tensor(8.2327, grad_fn=<DivBackward0>)
# 195tensor(7.7239, grad_fn=<DivBackward0>)
# 196tensor(7.8081, grad_fn=<DivBackward0>)
# 197tensor(8.4024, grad_fn=<DivBackward0>)
# 198tensor(7.9140, grad_fn=<DivBackward0>)
# 199tensor(7.6288, grad_fn=<DivBackward0>)
# 200tensor(8.2804, grad_fn=<DivBackward0>)
# 201tensor(8.1415, grad_fn=<DivBackward0>)
# 202tensor(7.7592, grad_fn=<DivBackward0>)
# 203tensor(8.3422, grad_fn=<DivBackward0>)
# 204tensor(8.4153, grad_fn=<DivBackward0>)
# 205tensor(8.0536, grad_fn=<DivBackward0>)
# 206tensor(7.7772, grad_fn=<DivBackward0>)
# 207tensor(8.4034, grad_fn=<DivBackward0>)
# 208tensor(7.9715, grad_fn=<DivBackward0>)
# 209tensor(7.5697, grad_fn=<DivBackward0>)
# 210tensor(8.0388, grad_fn=<DivBackward0>)
# 211tensor(8.0233, grad_fn=<DivBackward0>)
# 212tensor(8.0483, grad_fn=<DivBackward0>)
# 213tensor(8.1973, grad_fn=<DivBackward0>)
# 214tensor(7.9362, grad_fn=<DivBackward0>)
# 215tensor(7.9515, grad_fn=<DivBackward0>)
# 216tensor(8.0253, grad_fn=<DivBackward0>)
# 217tensor(7.4054, grad_fn=<DivBackward0>)
# 218tensor(8.2208, grad_fn=<DivBackward0>)
# 219tensor(8.2009, grad_fn=<DivBackward0>)
# 220tensor(8.6109, grad_fn=<DivBackward0>)
# 221tensor(8.0411, grad_fn=<DivBackward0>)
# 222tensor(7.8445, grad_fn=<DivBackward0>)
# 223tensor(8.1065, grad_fn=<DivBackward0>)
# 224tensor(8.2009, grad_fn=<DivBackward0>)
# 225tensor(7.3331, grad_fn=<DivBackward0>)
# 226tensor(8.0056, grad_fn=<DivBackward0>)
# 227tensor(8.0066, grad_fn=<DivBackward0>)
# 228tensor(8.1590, grad_fn=<DivBackward0>)
# 229tensor(7.4578, grad_fn=<DivBackward0>)
# 230tensor(8.2214, grad_fn=<DivBackward0>)
# 231tensor(8.1570, grad_fn=<DivBackward0>)
# 232tensor(8.2698, grad_fn=<DivBackward0>)
# 233tensor(8.1535, grad_fn=<DivBackward0>)
# 234tensor(7.8565, grad_fn=<DivBackward0>)
# 235tensor(8.3052, grad_fn=<DivBackward0>)
# 236tensor(7.9728, grad_fn=<DivBackward0>)
# 237tensor(7.7468, grad_fn=<DivBackward0>)
# 238tensor(8.3218, grad_fn=<DivBackward0>)
# 239tensor(7.8595, grad_fn=<DivBackward0>)
# 240tensor(8.3621, grad_fn=<DivBackward0>)
# 241tensor(8.3419, grad_fn=<DivBackward0>)
# 242tensor(7.9382, grad_fn=<DivBackward0>)
# 243tensor(8.2087, grad_fn=<DivBackward0>)
# 244tensor(7.8592, grad_fn=<DivBackward0>)
# 245tensor(7.7335, grad_fn=<DivBackward0>)
# 246tensor(7.7264, grad_fn=<DivBackward0>)
# 247tensor(7.6550, grad_fn=<DivBackward0>)
# 248tensor(7.7369, grad_fn=<DivBackward0>)
# 249tensor(8.0264, grad_fn=<DivBackward0>)
# 250tensor(8.3010, grad_fn=<DivBackward0>)
# 251tensor(8.1462, grad_fn=<DivBackward0>)
# 252tensor(8.1899, grad_fn=<DivBackward0>)
# 253tensor(7.7906, grad_fn=<DivBackward0>)
# 254tensor(8.0643, grad_fn=<DivBackward0>)
# 255tensor(8.1223, grad_fn=<DivBackward0>)
# 256tensor(8.4856, grad_fn=<DivBackward0>)
# 257tensor(7.9140, grad_fn=<DivBackward0>)
# 258tensor(8.1886, grad_fn=<DivBackward0>)
# 259tensor(7.7768, grad_fn=<DivBackward0>)
# 260tensor(8.2654, grad_fn=<DivBackward0>)
# 261tensor(8.2642, grad_fn=<DivBackward0>)
# 262tensor(8.0958, grad_fn=<DivBackward0>)
# 263tensor(7.5127, grad_fn=<DivBackward0>)
# 264tensor(7.8946, grad_fn=<DivBackward0>)
# 265tensor(8.3199, grad_fn=<DivBackward0>)
# 266tensor(8.1826, grad_fn=<DivBackward0>)
# 267tensor(7.8289, grad_fn=<DivBackward0>)
# 268tensor(7.9348, grad_fn=<DivBackward0>)
# 269tensor(8.1600, grad_fn=<DivBackward0>)
# 270tensor(7.9164, grad_fn=<DivBackward0>)
# 271tensor(7.9263, grad_fn=<DivBackward0>)
# 272tensor(8.2569, grad_fn=<DivBackward0>)
# 273tensor(7.8641, grad_fn=<DivBackward0>)
# 274tensor(8.1982, grad_fn=<DivBackward0>)
# 275tensor(8.0065, grad_fn=<DivBackward0>)
# 276tensor(8.0065, grad_fn=<DivBackward0>)
# 277tensor(8.1768, grad_fn=<DivBackward0>)
# 278tensor(8.1017, grad_fn=<DivBackward0>)
# 279tensor(8.2403, grad_fn=<DivBackward0>)
# 280tensor(8.2498, grad_fn=<DivBackward0>)
# 281tensor(7.8489, grad_fn=<DivBackward0>)
# 282tensor(8.1009, grad_fn=<DivBackward0>)
# 283tensor(8.1131, grad_fn=<DivBackward0>)
# 284tensor(8.3867, grad_fn=<DivBackward0>)
# 285tensor(7.6843, grad_fn=<DivBackward0>)
# 286tensor(8.0569, grad_fn=<DivBackward0>)
# 287tensor(8.3795, grad_fn=<DivBackward0>)
# 288tensor(8.0303, grad_fn=<DivBackward0>)
# 289tensor(7.9397, grad_fn=<DivBackward0>)
# 290tensor(8.2340, grad_fn=<DivBackward0>)
# 291tensor(7.7747, grad_fn=<DivBackward0>)
# 292tensor(7.8218, grad_fn=<DivBackward0>)
# 293tensor(7.9825, grad_fn=<DivBackward0>)
# 294tensor(8.2422, grad_fn=<DivBackward0>)
# 295tensor(7.7835, grad_fn=<DivBackward0>)
# 296tensor(8.3228, grad_fn=<DivBackward0>)
# 297tensor(8.1755, grad_fn=<DivBackward0>)
# 298tensor(8.0503, grad_fn=<DivBackward0>)
# 299tensor(8.5236, grad_fn=<DivBackward0>)
# 300tensor(8.3420, grad_fn=<DivBackward0>)
# 301tensor(8.0410, grad_fn=<DivBackward0>)
# 302tensor(8.1659, grad_fn=<DivBackward0>)
# 303tensor(8.2657, grad_fn=<DivBackward0>)
# 304tensor(7.9622, grad_fn=<DivBackward0>)
# 305tensor(8.1988, grad_fn=<DivBackward0>)
# 306tensor(8.1723, grad_fn=<DivBackward0>)
# 307tensor(8.2110, grad_fn=<DivBackward0>)
# 308tensor(8.0625, grad_fn=<DivBackward0>)
# 309tensor(8.2512, grad_fn=<DivBackward0>)
# 310tensor(7.8221, grad_fn=<DivBackward0>)
# 311tensor(8.2832, grad_fn=<DivBackward0>)
# 312tensor(8.1691, grad_fn=<DivBackward0>)
# 313tensor(8.1064, grad_fn=<DivBackward0>)
# 314tensor(8.3992, grad_fn=<DivBackward0>)
# 315tensor(7.8169, grad_fn=<DivBackward0>)
# 316tensor(7.7937, grad_fn=<DivBackward0>)
# 317tensor(7.9278, grad_fn=<DivBackward0>)
# 318tensor(8.1100, grad_fn=<DivBackward0>)
# 319tensor(8.3254, grad_fn=<DivBackward0>)
# 320tensor(8.2677, grad_fn=<DivBackward0>)
# 321tensor(8.3167, grad_fn=<DivBackward0>)
# 322tensor(7.8503, grad_fn=<DivBackward0>)
# 323tensor(7.8643, grad_fn=<DivBackward0>)
# 324tensor(8.2131, grad_fn=<DivBackward0>)
# 325tensor(7.6211, grad_fn=<DivBackward0>)
# 326tensor(8.4160, grad_fn=<DivBackward0>)
# 327tensor(8.6369, grad_fn=<DivBackward0>)
# 328tensor(8.0900, grad_fn=<DivBackward0>)
# 329tensor(8.4171, grad_fn=<DivBackward0>)
# 330tensor(7.8057, grad_fn=<DivBackward0>)
# 331tensor(8.2488, grad_fn=<DivBackward0>)
# 332tensor(8.2420, grad_fn=<DivBackward0>)
# 333tensor(8.1187, grad_fn=<DivBackward0>)
# 334tensor(8.1592, grad_fn=<DivBackward0>)
# 335tensor(7.8391, grad_fn=<DivBackward0>)
# 336tensor(8.0999, grad_fn=<DivBackward0>)
# 337tensor(8.0148, grad_fn=<DivBackward0>)
# 338tensor(8.2923, grad_fn=<DivBackward0>)
# 339tensor(8.6921, grad_fn=<DivBackward0>)
# 340tensor(8.1372, grad_fn=<DivBackward0>)
# 341tensor(8.1437, grad_fn=<DivBackward0>)
# 342tensor(8.2022, grad_fn=<DivBackward0>)
# 343tensor(8.4961, grad_fn=<DivBackward0>)
# 344tensor(8.3546, grad_fn=<DivBackward0>)
# 345tensor(7.8451, grad_fn=<DivBackward0>)
# 346tensor(8.1784, grad_fn=<DivBackward0>)
# 347tensor(7.8712, grad_fn=<DivBackward0>)
# 348tensor(8.4960, grad_fn=<DivBackward0>)
# 349tensor(7.7028, grad_fn=<DivBackward0>)
# 350tensor(7.8074, grad_fn=<DivBackward0>)
# 351tensor(7.9509, grad_fn=<DivBackward0>)
# 352tensor(8.1882, grad_fn=<DivBackward0>)
# 353tensor(7.3783, grad_fn=<DivBackward0>)
# 354tensor(8.0891, grad_fn=<DivBackward0>)
# 355tensor(8.2390, grad_fn=<DivBackward0>)
# 356tensor(8.0495, grad_fn=<DivBackward0>)
# 357tensor(8.4996, grad_fn=<DivBackward0>)
# 358tensor(7.7781, grad_fn=<DivBackward0>)
# 359tensor(7.9446, grad_fn=<DivBackward0>)
# 360tensor(8.1133, grad_fn=<DivBackward0>)
# 361tensor(7.7777, grad_fn=<DivBackward0>)
# 362tensor(8.1857, grad_fn=<DivBackward0>)
# 363tensor(7.8619, grad_fn=<DivBackward0>)
# 364tensor(7.9810, grad_fn=<DivBackward0>)
# 365tensor(8.1383, grad_fn=<DivBackward0>)
# 366tensor(8.1359, grad_fn=<DivBackward0>)
# 367tensor(7.5703, grad_fn=<DivBackward0>)
# 368tensor(8.2244, grad_fn=<DivBackward0>)
# 369tensor(8.9616, grad_fn=<DivBackward0>)
# 370tensor(8.3061, grad_fn=<DivBackward0>)
# 371tensor(8.2212, grad_fn=<DivBackward0>)
# 372tensor(8.6065, grad_fn=<DivBackward0>)
# 373tensor(8.1391, grad_fn=<DivBackward0>)
# 374tensor(7.9325, grad_fn=<DivBackward0>)
# 375tensor(7.4282, grad_fn=<DivBackward0>)
# 376tensor(7.5174, grad_fn=<DivBackward0>)
# 377tensor(7.7285, grad_fn=<DivBackward0>)
# 378tensor(8.2198, grad_fn=<DivBackward0>)
# 379tensor(8.3755, grad_fn=<DivBackward0>)
# 380tensor(8.1435, grad_fn=<DivBackward0>)
# 381tensor(8.6002, grad_fn=<DivBackward0>)
# 382tensor(8.4998, grad_fn=<DivBackward0>)
# 383tensor(8.2674, grad_fn=<DivBackward0>)
# 384tensor(8.1525, grad_fn=<DivBackward0>)
# 385tensor(7.7929, grad_fn=<DivBackward0>)
# 386tensor(7.8002, grad_fn=<DivBackward0>)
# 387tensor(7.8151, grad_fn=<DivBackward0>)
# 388tensor(7.9474, grad_fn=<DivBackward0>)
# 389tensor(7.6383, grad_fn=<DivBackward0>)
# 390tensor(8.0666, grad_fn=<DivBackward0>)
# 391tensor(8.1920, grad_fn=<DivBackward0>)
# 392tensor(7.8107, grad_fn=<DivBackward0>)
# 393tensor(7.8187, grad_fn=<DivBackward0>)
# 394tensor(7.7068, grad_fn=<DivBackward0>)
# 395tensor(7.2579, grad_fn=<DivBackward0>)
# 396tensor(8.1484, grad_fn=<DivBackward0>)
# 397tensor(7.9593, grad_fn=<DivBackward0>)
# 398tensor(7.3724, grad_fn=<DivBackward0>)
# 399tensor(8.2379, grad_fn=<DivBackward0>)
# 400tensor(8.4245, grad_fn=<DivBackward0>)
# 401tensor(8.1722, grad_fn=<DivBackward0>)
# 402tensor(8.1975, grad_fn=<DivBackward0>)
# 403tensor(8.2688, grad_fn=<DivBackward0>)
# 404tensor(7.7132, grad_fn=<DivBackward0>)
# 405tensor(8.5130, grad_fn=<DivBackward0>)
# 406tensor(8.2923, grad_fn=<DivBackward0>)
# 407tensor(8.0286, grad_fn=<DivBackward0>)
# 408tensor(7.7643, grad_fn=<DivBackward0>)
# 409tensor(7.9953, grad_fn=<DivBackward0>)
# 410tensor(7.8739, grad_fn=<DivBackward0>)
# 411tensor(8.3075, grad_fn=<DivBackward0>)
# 412tensor(7.7725, grad_fn=<DivBackward0>)
# 413tensor(8.9195, grad_fn=<DivBackward0>)
# 414tensor(7.8719, grad_fn=<DivBackward0>)
# 415tensor(7.6814, grad_fn=<DivBackward0>)
# 416tensor(7.9726, grad_fn=<DivBackward0>)
# 417tensor(8.2944, grad_fn=<DivBackward0>)
# 418tensor(8.1824, grad_fn=<DivBackward0>)
# 419tensor(7.5861, grad_fn=<DivBackward0>)
# 420tensor(7.6496, grad_fn=<DivBackward0>)
# 421tensor(8.0388, grad_fn=<DivBackward0>)
# 422tensor(7.8665, grad_fn=<DivBackward0>)
# 423tensor(7.5898, grad_fn=<DivBackward0>)
# 424tensor(7.7992, grad_fn=<DivBackward0>)
# 425tensor(7.7427, grad_fn=<DivBackward0>)
# 426tensor(7.9828, grad_fn=<DivBackward0>)
# 427tensor(7.2104, grad_fn=<DivBackward0>)
# 428tensor(8.1302, grad_fn=<DivBackward0>)
# 429tensor(8.1547, grad_fn=<DivBackward0>)
# 430tensor(8.6464, grad_fn=<DivBackward0>)
# 431tensor(7.9047, grad_fn=<DivBackward0>)
# 432tensor(8.0058, grad_fn=<DivBackward0>)
# 433tensor(7.6705, grad_fn=<DivBackward0>)
# 434tensor(7.7353, grad_fn=<DivBackward0>)
# 435tensor(7.9508, grad_fn=<DivBackward0>)
# 436tensor(8.0319, grad_fn=<DivBackward0>)
# 437tensor(7.4469, grad_fn=<DivBackward0>)
# 438tensor(7.7550, grad_fn=<DivBackward0>)
# 439tensor(7.7251, grad_fn=<DivBackward0>)
# 440tensor(8.1069, grad_fn=<DivBackward0>)
# 441tensor(7.7734, grad_fn=<DivBackward0>)
# 442tensor(7.7225, grad_fn=<DivBackward0>)
# 443tensor(7.9078, grad_fn=<DivBackward0>)
# 444tensor(7.7299, grad_fn=<DivBackward0>)
# 445tensor(8.1045, grad_fn=<DivBackward0>)
# 446tensor(8.1037, grad_fn=<DivBackward0>)
# 447tensor(7.8270, grad_fn=<DivBackward0>)
# 448tensor(7.1336, grad_fn=<DivBackward0>)
# 449tensor(7.8382, grad_fn=<DivBackward0>)
# 450tensor(7.8282, grad_fn=<DivBackward0>)
# 451tensor(7.5987, grad_fn=<DivBackward0>)
# 452tensor(8.3586, grad_fn=<DivBackward0>)
# 453tensor(8.3206, grad_fn=<DivBackward0>)
# 454tensor(8.0212, grad_fn=<DivBackward0>)
# 455tensor(7.6300, grad_fn=<DivBackward0>)
# 456tensor(7.8613, grad_fn=<DivBackward0>)
# 457tensor(7.6389, grad_fn=<DivBackward0>)
# 458tensor(8.1420, grad_fn=<DivBackward0>)
# 459tensor(7.5907, grad_fn=<DivBackward0>)
# 460tensor(8.0171, grad_fn=<DivBackward0>)
# 461tensor(7.7890, grad_fn=<DivBackward0>)
# 462tensor(7.6679, grad_fn=<DivBackward0>)
# 463tensor(7.9465, grad_fn=<DivBackward0>)
# 464tensor(8.3470, grad_fn=<DivBackward0>)
# 465tensor(7.9576, grad_fn=<DivBackward0>)
# 466tensor(7.5920, grad_fn=<DivBackward0>)
# 467tensor(8.2002, grad_fn=<DivBackward0>)
# 468tensor(7.9857, grad_fn=<DivBackward0>)
# 469tensor(8.0463, grad_fn=<DivBackward0>)
# 470tensor(8.0972, grad_fn=<DivBackward0>)
# 471tensor(8.4022, grad_fn=<DivBackward0>)
# 472tensor(8.2691, grad_fn=<DivBackward0>)
# 473tensor(7.7933, grad_fn=<DivBackward0>)
# 474tensor(7.7477, grad_fn=<DivBackward0>)
# 475tensor(7.8951, grad_fn=<DivBackward0>)
# 476tensor(8.0221, grad_fn=<DivBackward0>)
# 477tensor(7.9458, grad_fn=<DivBackward0>)
# 478tensor(7.6020, grad_fn=<DivBackward0>)
# 479tensor(7.9582, grad_fn=<DivBackward0>)
# 480tensor(8.4763, grad_fn=<DivBackward0>)
# 481tensor(7.6392, grad_fn=<DivBackward0>)
# 482tensor(8.2805, grad_fn=<DivBackward0>)
# 483tensor(8.0291, grad_fn=<DivBackward0>)
# 484tensor(8.1656, grad_fn=<DivBackward0>)
# 485tensor(7.8515, grad_fn=<DivBackward0>)
# 486tensor(7.6716, grad_fn=<DivBackward0>)
# 487tensor(8.0012, grad_fn=<DivBackward0>)
# 488tensor(8.1812, grad_fn=<DivBackward0>)
# 489tensor(7.7764, grad_fn=<DivBackward0>)
# 490tensor(8.2098, grad_fn=<DivBackward0>)
# 491tensor(7.6018, grad_fn=<DivBackward0>)
# 492tensor(7.8312, grad_fn=<DivBackward0>)
# 493tensor(8.1493, grad_fn=<DivBackward0>)
# 494tensor(7.7750, grad_fn=<DivBackward0>)
# 495tensor(8.3103, grad_fn=<DivBackward0>)
# 496tensor(7.6387, grad_fn=<DivBackward0>)
# 497tensor(7.7532, grad_fn=<DivBackward0>)
# 498tensor(7.7586, grad_fn=<DivBackward0>)
# 499tensor(7.9370, grad_fn=<DivBackward0>)
# 500tensor(8.1193, grad_fn=<DivBackward0>)
# 501tensor(8.3990, grad_fn=<DivBackward0>)
# 502tensor(7.7537, grad_fn=<DivBackward0>)
# 503tensor(8.0446, grad_fn=<DivBackward0>)
# 504tensor(7.9990, grad_fn=<DivBackward0>)
# 505tensor(8.7350, grad_fn=<DivBackward0>)
# 506tensor(7.7698, grad_fn=<DivBackward0>)
# 507tensor(8.0090, grad_fn=<DivBackward0>)
# 508tensor(7.6915, grad_fn=<DivBackward0>)
# 509tensor(8.4882, grad_fn=<DivBackward0>)
# 510tensor(7.7971, grad_fn=<DivBackward0>)
# 511tensor(7.5890, grad_fn=<DivBackward0>)
# 512tensor(8.0933, grad_fn=<DivBackward0>)
# 513tensor(8.4373, grad_fn=<DivBackward0>)
# 514tensor(8.0612, grad_fn=<DivBackward0>)
# 515tensor(8.5630, grad_fn=<DivBackward0>)
# 516tensor(7.6972, grad_fn=<DivBackward0>)
# 517tensor(7.6608, grad_fn=<DivBackward0>)
# 518tensor(8.1164, grad_fn=<DivBackward0>)
# 519tensor(8.1312, grad_fn=<DivBackward0>)
# 520tensor(7.7784, grad_fn=<DivBackward0>)
# 521tensor(8.1475, grad_fn=<DivBackward0>)
# 522tensor(8.0277, grad_fn=<DivBackward0>)
# 523tensor(8.2903, grad_fn=<DivBackward0>)
# 524tensor(8.3914, grad_fn=<DivBackward0>)
# 525tensor(8.1367, grad_fn=<DivBackward0>)
# 526tensor(7.6855, grad_fn=<DivBackward0>)
# 527tensor(8.2501, grad_fn=<DivBackward0>)
# 528tensor(7.4548, grad_fn=<DivBackward0>)
# 529tensor(8.5252, grad_fn=<DivBackward0>)
# 530tensor(7.5383, grad_fn=<DivBackward0>)
# 531tensor(7.8650, grad_fn=<DivBackward0>)
# 532tensor(8.2309, grad_fn=<DivBackward0>)
# 533tensor(8.2255, grad_fn=<DivBackward0>)
# 534tensor(8.2658, grad_fn=<DivBackward0>)
# 535tensor(7.9471, grad_fn=<DivBackward0>)
# 536tensor(7.5339, grad_fn=<DivBackward0>)
# 537tensor(8.1258, grad_fn=<DivBackward0>)
# 538tensor(7.5268, grad_fn=<DivBackward0>)
# 539tensor(8.5245, grad_fn=<DivBackward0>)
# 540tensor(7.9795, grad_fn=<DivBackward0>)
# 541tensor(7.8099, grad_fn=<DivBackward0>)
# 542tensor(8.0640, grad_fn=<DivBackward0>)
# 543tensor(7.5768, grad_fn=<DivBackward0>)
# 544tensor(8.5574, grad_fn=<DivBackward0>)
# 545tensor(8.0852, grad_fn=<DivBackward0>)
# 546tensor(8.1649, grad_fn=<DivBackward0>)
# 547tensor(7.8928, grad_fn=<DivBackward0>)
# 548tensor(7.4493, grad_fn=<DivBackward0>)
# 549tensor(8.4081, grad_fn=<DivBackward0>)
# 550tensor(7.8392, grad_fn=<DivBackward0>)
# 551tensor(7.9368, grad_fn=<DivBackward0>)
# 552tensor(8.0006, grad_fn=<DivBackward0>)
# 553tensor(7.9683, grad_fn=<DivBackward0>)
# 554tensor(7.7367, grad_fn=<DivBackward0>)
# 555tensor(8.3935, grad_fn=<DivBackward0>)
# 556tensor(7.5549, grad_fn=<DivBackward0>)
# 557tensor(8.1921, grad_fn=<DivBackward0>)
# 558tensor(7.4315, grad_fn=<DivBackward0>)
# 559tensor(7.7513, grad_fn=<DivBackward0>)
# 560tensor(7.6862, grad_fn=<DivBackward0>)
# 561tensor(7.8590, grad_fn=<DivBackward0>)
# 562tensor(8.1413, grad_fn=<DivBackward0>)
# 563tensor(7.7856, grad_fn=<DivBackward0>)
# 564tensor(8.0820, grad_fn=<DivBackward0>)
# 565tensor(7.9367, grad_fn=<DivBackward0>)
# 566tensor(8.0631, grad_fn=<DivBackward0>)
# 567tensor(7.7086, grad_fn=<DivBackward0>)
# 568tensor(8.4768, grad_fn=<DivBackward0>)
# 569tensor(7.8900, grad_fn=<DivBackward0>)
# 570tensor(8.0826, grad_fn=<DivBackward0>)
# 571tensor(8.1038, grad_fn=<DivBackward0>)
# 572tensor(8.1693, grad_fn=<DivBackward0>)
# 573tensor(8.4042, grad_fn=<DivBackward0>)
# 574tensor(7.9753, grad_fn=<DivBackward0>)
# 575tensor(8.1736, grad_fn=<DivBackward0>)
# 576tensor(8.1112, grad_fn=<DivBackward0>)
# 577tensor(8.0553, grad_fn=<DivBackward0>)
# 578tensor(8.0184, grad_fn=<DivBackward0>)
# 579tensor(8.4865, grad_fn=<DivBackward0>)
# 580tensor(8.0435, grad_fn=<DivBackward0>)
# 581tensor(7.8598, grad_fn=<DivBackward0>)
# 582tensor(7.7076, grad_fn=<DivBackward0>)
# 583tensor(7.7970, grad_fn=<DivBackward0>)
# 584tensor(8.4634, grad_fn=<DivBackward0>)
# 585tensor(7.5228, grad_fn=<DivBackward0>)
# 586tensor(8.3576, grad_fn=<DivBackward0>)
# 587tensor(7.8997, grad_fn=<DivBackward0>)
# 588tensor(8.0295, grad_fn=<DivBackward0>)
# 589tensor(8.2652, grad_fn=<DivBackward0>)
# 590tensor(7.9856, grad_fn=<DivBackward0>)
# 591tensor(8.0534, grad_fn=<DivBackward0>)
# 592tensor(7.8752, grad_fn=<DivBackward0>)
# 593tensor(8.1557, grad_fn=<DivBackward0>)
# 594tensor(7.7540, grad_fn=<DivBackward0>)
# 595tensor(7.8365, grad_fn=<DivBackward0>)
# 596tensor(7.7868, grad_fn=<DivBackward0>)
# 597tensor(7.8178, grad_fn=<DivBackward0>)
# 598tensor(8.0589, grad_fn=<DivBackward0>)
# 599tensor(7.9906, grad_fn=<DivBackward0>)
# 600tensor(7.6994, grad_fn=<DivBackward0>)
# 601tensor(8.1118, grad_fn=<DivBackward0>)
# 602tensor(8.0402, grad_fn=<DivBackward0>)
# 603tensor(7.7663, grad_fn=<DivBackward0>)
# 604tensor(7.9454, grad_fn=<DivBackward0>)
# 605tensor(7.3883, grad_fn=<DivBackward0>)
# 606tensor(7.1767, grad_fn=<DivBackward0>)
# 607tensor(8.2146, grad_fn=<DivBackward0>)
# 608tensor(8.3451, grad_fn=<DivBackward0>)
# 609tensor(8.5267, grad_fn=<DivBackward0>)
# 610tensor(8.5743, grad_fn=<DivBackward0>)
# 611tensor(7.8657, grad_fn=<DivBackward0>)
# 612tensor(8.0630, grad_fn=<DivBackward0>)
# 613tensor(7.9621, grad_fn=<DivBackward0>)
# 614tensor(8.3082, grad_fn=<DivBackward0>)
# 615tensor(7.8556, grad_fn=<DivBackward0>)
# 616tensor(8.0087, grad_fn=<DivBackward0>)
# 617tensor(7.9979, grad_fn=<DivBackward0>)
# 618tensor(7.4707, grad_fn=<DivBackward0>)
# 619tensor(8.2827, grad_fn=<DivBackward0>)
# 620tensor(8.4017, grad_fn=<DivBackward0>)
# 621tensor(8.4328, grad_fn=<DivBackward0>)
# 622tensor(7.5186, grad_fn=<DivBackward0>)
# 623tensor(7.9995, grad_fn=<DivBackward0>)
# 624tensor(7.7447, grad_fn=<DivBackward0>)
# 625tensor(7.7903, grad_fn=<DivBackward0>)
# 626tensor(7.6754, grad_fn=<DivBackward0>)
# 627tensor(8.0910, grad_fn=<DivBackward0>)
# 628tensor(7.7218, grad_fn=<DivBackward0>)
# 629tensor(7.6068, grad_fn=<DivBackward0>)
# 630tensor(7.9248, grad_fn=<DivBackward0>)
# 631tensor(8.6000, grad_fn=<DivBackward0>)
# 632tensor(7.5773, grad_fn=<DivBackward0>)
# 633tensor(7.7808, grad_fn=<DivBackward0>)
# 634tensor(8.2031, grad_fn=<DivBackward0>)
# 635tensor(7.7952, grad_fn=<DivBackward0>)
# 636tensor(8.0997, grad_fn=<DivBackward0>)
# 637tensor(7.3346, grad_fn=<DivBackward0>)
# 638tensor(7.4090, grad_fn=<DivBackward0>)
# 639tensor(7.4752, grad_fn=<DivBackward0>)
# 640tensor(7.7265, grad_fn=<DivBackward0>)
# 641tensor(7.4538, grad_fn=<DivBackward0>)
# 642tensor(7.8786, grad_fn=<DivBackward0>)
# 643tensor(7.9716, grad_fn=<DivBackward0>)
# 644tensor(7.2534, grad_fn=<DivBackward0>)
# 645tensor(8.2819, grad_fn=<DivBackward0>)
# 646tensor(7.8463, grad_fn=<DivBackward0>)
# 647tensor(7.7843, grad_fn=<DivBackward0>)
# 648tensor(7.4940, grad_fn=<DivBackward0>)
# 649tensor(8.2762, grad_fn=<DivBackward0>)
# 650tensor(8.1168, grad_fn=<DivBackward0>)
# 651tensor(7.9702, grad_fn=<DivBackward0>)
# 652tensor(8.3779, grad_fn=<DivBackward0>)
# 653tensor(8.5437, grad_fn=<DivBackward0>)
# 654tensor(8.6042, grad_fn=<DivBackward0>)
# 655tensor(7.9891, grad_fn=<DivBackward0>)
# 656tensor(7.8173, grad_fn=<DivBackward0>)
# 657tensor(8.4977, grad_fn=<DivBackward0>)
# 658tensor(8.3562, grad_fn=<DivBackward0>)
# 659tensor(8.2919, grad_fn=<DivBackward0>)
# 660tensor(7.9103, grad_fn=<DivBackward0>)
# 661tensor(8.4117, grad_fn=<DivBackward0>)
# 662tensor(8.2755, grad_fn=<DivBackward0>)
# 663tensor(7.6821, grad_fn=<DivBackward0>)
# 664tensor(8.0632, grad_fn=<DivBackward0>)
# 665tensor(8.0514, grad_fn=<DivBackward0>)
# 666tensor(7.9505, grad_fn=<DivBackward0>)
# 667tensor(8.4224, grad_fn=<DivBackward0>)
# 668tensor(8.2264, grad_fn=<DivBackward0>)
# 669tensor(8.1701, grad_fn=<DivBackward0>)
# 670tensor(7.5419, grad_fn=<DivBackward0>)
# 671tensor(8.0903, grad_fn=<DivBackward0>)
# 672tensor(8.0366, grad_fn=<DivBackward0>)
# 673tensor(8.3734, grad_fn=<DivBackward0>)
# 674tensor(7.6538, grad_fn=<DivBackward0>)
# 675tensor(7.7702, grad_fn=<DivBackward0>)
# 676tensor(7.9286, grad_fn=<DivBackward0>)
# 677tensor(7.8864, grad_fn=<DivBackward0>)
# 678tensor(8.2982, grad_fn=<DivBackward0>)
# 679tensor(7.6317, grad_fn=<DivBackward0>)
# 680tensor(8.0462, grad_fn=<DivBackward0>)
# 681tensor(7.6584, grad_fn=<DivBackward0>)
# 682tensor(8.4236, grad_fn=<DivBackward0>)
# 683tensor(8.0397, grad_fn=<DivBackward0>)
# 684tensor(7.8074, grad_fn=<DivBackward0>)
# 685tensor(7.8393, grad_fn=<DivBackward0>)
# 686tensor(8.5135, grad_fn=<DivBackward0>)
# 687tensor(8.2842, grad_fn=<DivBackward0>)
# 688tensor(8.2742, grad_fn=<DivBackward0>)
# 689tensor(8.2244, grad_fn=<DivBackward0>)
# 690tensor(8.0366, grad_fn=<DivBackward0>)
# 691tensor(8.1906, grad_fn=<DivBackward0>)
# 692tensor(7.8018, grad_fn=<DivBackward0>)
# 693tensor(7.9742, grad_fn=<DivBackward0>)
# 694tensor(8.2000, grad_fn=<DivBackward0>)
# 695tensor(7.5405, grad_fn=<DivBackward0>)
# 696tensor(8.0412, grad_fn=<DivBackward0>)
# 697tensor(7.5391, grad_fn=<DivBackward0>)
# 698tensor(8.2377, grad_fn=<DivBackward0>)
# 699tensor(8.7897, grad_fn=<DivBackward0>)
# 700tensor(8.2877, grad_fn=<DivBackward0>)

# %%
os.chdir('C:\\Users\\Ji Qi\\Documents\\GitHub\\ST-Aim3')
os.getcwd()
PATH = 'vgae_model_for_simulation.pth'
torch.save(model, PATH)

model = torch.load(PATH)
model.eval()
# Out:
# VGAE(
#   (encoder): Encoder(
#     (conv1): GCNConv(10, 4)
#     (conv_mu): GCNConv(4, 2)
#     (conv_logstd): GCNConv(4, 2)
#   )
#   (decoder): InnerProductDecoder()
# )

# %%
# get mu and logstd 

mu_list_in_data = []
logstd_list_in_data = []
for i in range(len(dataset)):
    train_data = dataset[i]
    mu = model.encode(train_data.x, train_data.edge_index)
    mu_list_in_data.append(np.asarray(mu.detach()))

mu_list_reshape = []
n = len(dataset)
for i in range(n):
    mu_list_reshape.append(mu_list_in_data[i].reshape((out_channels * n_node)))

# %%
# input data scatter 
import matplotlib.pyplot as plt
def plot_mu_graph(mu):
    
    n_node = mu.shape[0]
    annotations = [str(i+1) for i in range(n_node)]
    colors = plt.cm.rainbow(np.linspace(0, 1, n_node))
    plt.scatter(mu[:,0],mu[:,1],c=colors, s=100)
    
    for i, label in enumerate(annotations):
        plt.annotate(label, (mu[i,0], mu[i,1]), fontsize=14)

        
plt.subplots(figsize=(20,20))

for graph_i in range(30):
    plt.subplot(5, 6, graph_i+1)
    plot_mu_graph(mu_list_in_data[graph_i])

# %%
# original data mu scatter
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
def plot_scatter_for_mu(mu_list):
    column_names = ["x", "y"]
    mu_for_plot = pd.DataFrame(columns = column_names, data=np.vstack(mu_list))
    mu_for_plot["label"] = list(range(10))*len(mu_list)
    x = mu_for_plot["x"]
    y = mu_for_plot["y"]
    c = mu_for_plot["label"]
    fig, ax = plt.subplots(figsize=(10,10))
    scatter = ax.scatter(x, y, c=c)

    # produce a legend with the unique colors from the scatter
    legend1 = ax.legend(*scatter.legend_elements(),
                        loc="lower left", title="Classes")
    ax.add_artist(legend1)

    plt.grid()
    plt.show()

plot_scatter_for_mu(mu_list_in_data)

# %%
# original adj matrices

import matplotlib.pyplot as plt
fig, ax = plt.subplots(5, 5, figsize=(10,10))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.imshow(simu_graph.simu_adj_m()[i], cmap="Greys")

# %%
# original data first 5 vs. last 5
simu_graph = SimuData(n_graph=30)
dataset = simu_graph.graph_dataset()
n_node = simu_graph.n_node

colors = ['#3DAE43', '#67E332','#008000', '#006400', '#228B22',
          '#CD5C5C','#C71585', '#FF4500', '#DB7093', '#FF0000']
mu_list = []
for i in range(len(dataset)):
    train_data = dataset[i]
    mu = model.encode(train_data.x, train_data.edge_index)
    mu_list.append(np.asarray(mu.detach()))

plt.figure(figsize=(10,10))
for node_i in range(n_node):
    
    node_mu = np.empty((0, 2))
    for graph_i in range(len(mu_list)):
    
        node_mu = np.vstack((node_mu, mu_list[graph_i][node_i, :]))
    
    plt.scatter(node_mu[:,0],node_mu[:,1], c=colors[node_i],alpha=0.8)

plt.show()

# %%
# Gaussian distribution for generating mu

import scipy.stats as stats
data_mu = np.zeros((n, out_channels * n_node))
for i in range(n):
    data_mu[i, :] = mu_list_reshape[i]

from sklearn.mixture import GaussianMixture

gm_mu = GaussianMixture(n_components=1, random_state=0).fit(data_mu)
gm_mu.weights_[0] = 1
# Out:
# C:\Users\Ji Qi\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
# got mean and cov for mu generating distribution
means_normal = gm_mu.means_
cov_normal = gm_mu.covariances_
means_normal = np.asarray(means_normal.tolist()[0])
cov_normal = np.asarray(cov_normal.tolist()[0])

# %%
def compute_centrality(mat):
    return (np.sum(mat, axis=0)/mat.shape[0])

# %%
def sample_adj_mat(filter_value=0.75, filter_eye=True):
    model.__mu__ = torch.from_numpy((np.random.multivariate_normal(mean=means_normal,cov=cov_normal)).reshape((n_node,out_channels)))
    z = model.__mu__
    model.decode(z, edge_index)
    adj_mat = np.zeros((n_node, n_node))
    for i in range(n_node*n_node):
        adj_mat[int(edge_index[0, i]), int(edge_index[1, i])] = (model.decode(z, edge_index)[i].detach().numpy()).item()
    adj_mat[adj_mat < filter_value] = 0
    if filter_eye:
        for i in range(adj_mat.shape[0]):
            adj_mat[i,i]=0
    return adj_mat, model.__mu__

# %%
# generate adjacency matrices

generated_from_simu = []
generated_simu_centrality = []

import matplotlib.pyplot as plt
fig, ax = plt.subplots(5, 10, figsize=(20,10))
adj_mat_list = []
mu_list = []
for i in range(50):
    plt.subplot(5, 10, i+1)
    adj_mat, mu_sample = sample_adj_mat(filter_value=0)
    generated_from_simu.append(adj_mat)
    generated_simu_centrality.append(compute_centrality(adj_mat))
    adj_mat_list.append(adj_mat)
    mu_list.append(mu_sample.detach().numpy())
    plt.imshow(adj_mat, cmap="Greys")

# %%
plt.subplots(figsize=(20,20))

for graph_i in range(25):
    plt.subplot(5, 5, graph_i+1)
    plot_mu_graph(mu_list[graph_i])

# %%
simu_adj_list = []
simu_centrality_list = []
for i in range(30):
    adj_mat = simu_graph.simu_adj_m()[i].detach().numpy()
    simu_adj_list.append(adj_mat)
    simu_centrality_list.append(compute_centrality(adj_mat))

# %%
from scipy import stats
res = stats.ttest_ind(generated_simu_centrality, simu_centrality_list, 
                      equal_var=True, axis=0)

display(res)
# Out:
# Ttest_indResult(statistic=array([ 21.49204592,  22.46572357,  19.39675131,  16.13384179,
#         23.49193284, 105.56586203,  51.75678449,  88.00340894,
#         88.30095801,  78.93449903]), pvalue=array([1.65458268e-34, 8.39365262e-36, 1.41931306e-31, 1.44102453e-26,
#        4.01164853e-37, 6.23301755e-86, 3.77291006e-62, 8.08384450e-80,
#        6.22871282e-80, 3.55868240e-76]))

# %%
np.mean(np.vstack(generated_simu_centrality), axis=0)
# Out:
# array([0.48951525, 0.4915928 , 0.50100901, 0.50128871, 0.49748699,
#        0.36878499, 0.3858556 , 0.37466052, 0.3755383 , 0.38576536])

# %%
np.mean(np.vstack(simu_centrality_list), axis=0)
# Out:
# array([0.21333332, 0.20999998, 0.20666668, 0.22      , 0.20333333,
#        0.        , 0.        , 0.        , 0.        , 0.        ],
#       dtype=float32)
