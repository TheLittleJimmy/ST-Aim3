# %%
import torch
from torch_geometric.utils import (negative_sampling, remove_self_loops,
                                   add_self_loops)
EPS = 1e-15
MAX_LOGSTD = 10

class InnerProductDecoder(torch.nn.Module):
    r"""The inner product decoder from the `"Variational Graph Auto-Encoders"
    <https://arxiv.org/abs/1611.07308>`_ paper

    .. math::
        \sigma(\mathbf{Z}\mathbf{Z}^{\top})

    where :math:`\mathbf{Z} \in \mathbb{R}^{N \times d}` denotes the latent
    space produced by the encoder."""
    def forward(self, z, edge_index, sigmoid=True):
        r"""Decodes the latent variables :obj:`z` into edge probabilities for
        the given node-pairs :obj:`edge_index`.

        Args:
            z (Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        value = (z[edge_index[0]] * z[edge_index[1]]).sum(dim=1)
        return torch.sigmoid(value) if sigmoid else value


    def forward_all(self, z, sigmoid=True):
        r"""Decodes the latent variables :obj:`z` into a probabilistic dense
        adjacency matrix.

        Args:
            z (Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        adj = torch.matmul(z, z.t())
        return torch.sigmoid(adj) if sigmoid else adj



class GAE(torch.nn.Module):
    r"""The Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper based on user-defined encoder and decoder models.

    Args:
        encoder (Module): The encoder module.
        decoder (Module, optional): The decoder module. If set to :obj:`None`,
            will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """
    def __init__(self, encoder, decoder=None):
        super(GAE, self).__init__()
        self.encoder = encoder
        self.decoder = InnerProductDecoder() if decoder is None else decoder
        GAE.reset_parameters(self)

    def reset_parameters(self):
        reset(self.encoder)
        reset(self.decoder)


    def encode(self, *args, **kwargs):
        r"""Runs the encoder and computes node-wise latent variables."""
        return self.encoder(*args, **kwargs)


    def decode(self, *args, **kwargs):
        r"""Runs the decoder and computes edge probabilities."""
        return self.decoder(*args, **kwargs)


    def recon_loss(self, z, pos_edge_index, neg_edge_index=None):
        r"""Given latent variables :obj:`z`, computes the binary cross
        entropy loss for positive edges :oenbj:`pos_edge_index` and negative
        sampled edges.

        Args:
            z (Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (LongTensor): The positive edges to train against.
            neg_edge_index (LongTensor, optional): The negative edges to train
                against. If not given, uses negative sampling to calculate
                negative edges. (default: :obj:`None`)
        """

        pos_loss = -torch.log(
            self.decoder(z, pos_edge_index, sigmoid=True) + EPS).mean()

        # Do not include self-loops in negative samples
        pos_edge_index, _ = remove_self_loops(pos_edge_index)
        pos_edge_index, _ = add_self_loops(pos_edge_index)
        if neg_edge_index is None:
            neg_edge_index = negative_sampling(pos_edge_index, z.size(0))
        neg_loss = -torch.log(1 -
                              self.decoder(z, neg_edge_index, sigmoid=True) +
                              EPS).mean()

        return pos_loss + neg_loss


    def test(self, z, pos_edge_index, neg_edge_index):
        r"""Given latent variables :obj:`z`, positive edges
        :obj:`pos_edge_index` and negative edges :obj:`neg_edge_index`,
        computes area under the ROC curve (AUC) and average precision (AP)
        scores.

        Args:
            z (Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (LongTensor): The positive edges to evaluate
                against.
            neg_edge_index (LongTensor): The negative edges to evaluate
                against.
        """
        from sklearn.metrics import roc_auc_score, average_precision_score

        pos_y = z.new_ones(pos_edge_index.size(1))
        neg_y = z.new_zeros(neg_edge_index.size(1))
        y = torch.cat([pos_y, neg_y], dim=0)

        pos_pred = self.decoder(z, pos_edge_index, sigmoid=True)
        neg_pred = self.decoder(z, neg_edge_index, sigmoid=True)
        pred = torch.cat([pos_pred, neg_pred], dim=0)
        
        y, pred = y.detach().cpu().numpy(), pred.detach().cpu().numpy()

        return roc_auc_score(y, pred), average_precision_score(y, pred)



class VGAE(GAE):
    r"""The Variational Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper.

    Args:
        encoder (Module): The encoder module to compute :math:`\mu` and
            :math:`\log\sigma^2`.
        decoder (Module, optional): The decoder module. If set to :obj:`None`,
            will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """
    def __init__(self, encoder, decoder=None):
        super(VGAE, self).__init__(encoder, decoder)

    def reparametrize(self, mu, logstd):
        if self.training:
            return mu + torch.randn_like(logstd) * torch.exp(logstd)
        else:
            return mu
    
    def encode(self, *args, **kwargs):
        """"""
        self.__mu__, self.__logstd__ = self.encoder(*args, **kwargs)
        self.__logstd__ = self.__logstd__.clamp(max=MAX_LOGSTD)
        z = self.reparametrize(self.__mu__, self.__logstd__)
        return z

    def kl_loss(self, mu=None, logstd=None):
        r"""Computes the KL loss, either for the passed arguments :obj:`mu`
        and :obj:`logstd`, or based on latent variables from last encoding.

        Args:
            mu (Tensor, optional): The latent space for :math:`\mu`. If set to
                :obj:`None`, uses the last computation of :math:`mu`.
                (default: :obj:`None`)
            logstd (Tensor, optional): The latent space for
                :math:`\log\sigma`.  If set to :obj:`None`, uses the last
                computation of :math:`\log\sigma^2`.(default: :obj:`None`)
        """
        mu = self.__mu__ if mu is None else mu
        logstd = self.__logstd__ if logstd is None else logstd.clamp(
            max=MAX_LOGSTD)
        return -0.5 * torch.mean(
            torch.sum(1 + 2 * logstd - mu**2 - logstd.exp()**2, dim=1))

# %%
import torch
from torch.autograd.grad_mode import F
from torch_geometric.data import Data
from torch_geometric.datasets import Planetoid
import torch_geometric.transforms as T
from torch_geometric.nn import GCNConv
from torch_geometric.utils import train_test_split_edges
from torch_geometric.nn import VGAE

import scipy.sparse as sp
import numpy as np
import networkx as nx

class SimuData():
    """Simulate graph data"""
    def __init__(self, p=0.5, n_node=10, n_graph=30):
        self.n_node = n_node
        self.n_graph = n_graph
        self.p = p

    def simu_adj_wgh(self):
        adj_list = []

        for i in range(self.n_graph):
            ## zero matrix
            A = torch.zeros(self.n_node, self.n_node)

            # first five nodes weights: uniform(0,1)A[:5,:5] = W
            W = torch.rand(5,5)

            ## symmetric
            i, j = torch.triu_indices(5, 5)
            W[i, j] = W.T[i, j]

            A[:5,:5] = W
            adj_list.append(A)  

        return adj_list

    def simu_adj_diag(self):
        adj_list = []

        for i in range(self.n_graph):
            A = torch.eye(self.n_node)
            adj_list.append(A)  

        return adj_list

    def simu_adj_m(self):
        """generating adjacency matrix"""
        adj_wgh = self.simu_adj_wgh()
        #adj_wgh = self.simu_adj_diag()
        adj_m_list =[]
        for _, adj in enumerate(adj_wgh):
            adj[adj>=1-self.p] = 1
            adj[adj<1-self.p] = 0
            for i in range(adj.shape[0]):
                adj[i, i] = 0
            adj_m_list.append(adj)    
        return adj_m_list

    def graph_dataset(self):
        dataset =[]
        simu_adj = self.simu_adj_m()

        for _, adj in enumerate(simu_adj):
            edge_index_temp = sp.coo_matrix(adj)
            indices = np.vstack((edge_index_temp.row, edge_index_temp.col))
            edge_index_A = torch.LongTensor(indices) 
            x = self.get_x_feature()
            data = Data(x=x, edge_index=edge_index_A)
            dataset.append(data)

        return dataset

    def get_x_feature(self):
        x = torch.arange(self.n_node)
        x_onehot = torch.eye(self.n_node)[x,:] 

        return torch.FloatTensor(x_onehot)


class Encoder(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super(Encoder, self).__init__()
        self.conv1 = GCNConv(in_channels, 2 * out_channels, cached=False) 
        self.conv_mu = GCNConv(2 * out_channels, out_channels, cached=False)
        self.conv_logstd = GCNConv(2 * out_channels, out_channels, cached=False)

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index).relu()
        return self.conv_mu(x, edge_index), self.conv_logstd(x, edge_index)


transform = T.Compose([
            T.NormalizeFeatures(),
            T.RandomLinkSplit(num_val=0, num_test=0, is_undirected=True,
                            split_labels=True, add_negative_train_samples=False),])

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.optim import Adam
import torch.nn.functional as F
import numpy as np
import scipy.sparse as sp
from scipy.sparse import csr_matrix


class LoadData():
    """Load graph data"""
    def __init__(self, file_path, samples, n_node=38):
        self.samples = samples
        self.file_path = file_path
        self.nSample = len(samples)
        self.n_node = n_node

    def get_adj_wgh(self):
        """generating adjacency matrix"""
        adj_orig_list =[]
        for sample in self.samples:
            f_name = self.file_path + ".".join([sample])
            adj   = np.asarray(pd.read_csv(f_name, index_col = 0, iterator = False))
            adj_orig_list.append(adj)    

        return adj_orig_list

    def get_adj_label(self):
        adj_m = self.get_adj_m()
        adj_label_list =[]
        
        for _, adj in enumerate(adj_m):
            adj_label = adj + sp.eye(adj.shape[0])
            adj_label = sparse_to_tuple(sp.coo_matrix(adj_label))
            #adj_label = sparse_to_tuple(adj_label)
            adj_label = torch.sparse.FloatTensor(torch.LongTensor(adj_label[0].T), 
                            torch.FloatTensor(adj_label[1]), 
                            torch.Size(adj_label[2]))
            adj_label_list.append(adj_label)
        return adj_label_list

    def get_adj_norm(self):
        adj_m = self.get_adj_m()
        adj_norm_list =[]

        for _, adj in enumerate(adj_m):
            adj_norm = preprocess_graph(adj)
            adj_norm = torch.sparse.FloatTensor(torch.LongTensor(adj_norm[0].T), 
                            torch.FloatTensor(adj_norm[1]), 
                            torch.Size(adj_norm[2]))
            adj_norm_list.append(adj_norm)

        return adj_norm_list

    def get_adj_m(self):
        adj_wgh = self.get_adj_wgh()
        adj_m_list =[]
        for _, adj in enumerate(adj_wgh):
            adj[adj>0] = 1
            for i in range(38):
                adj[i, i] = 0
            for i in range(38):
                for j in range(38):
                    if adj[i, j] == 1:
                        adj[j, i] = 1
            adj_m_list.append(adj)    
        return adj_m_list

    def get_feature(self):
        """generating feature matrix X"""
        adj_wgh = self.get_adj_wgh()
        x_list = []
        for _, adj in enumerate(adj_wgh):
            x_feature  = adj
            x_feature  = csr_matrix(x_feature)
            x_feature  = sparse_to_tuple(x_feature)
            x_feature  = torch.sparse.FloatTensor(torch.LongTensor(x_feature[0].T), 
                            torch.FloatTensor(x_feature[1]), 
                            torch.Size(x_feature[2]))
            x_list.append(x_feature)
        return x_list

    def get_x_feature(self):
        x = torch.arange(self.n_node)
        x_onehot = torch.eye(self.n_node)[x,:] 

        return torch.FloatTensor(x_onehot)   

    def graph_dataset(self):
        dataset =[]
        simu_adj = self.get_adj_m()

        for _, adj in enumerate(simu_adj):
            edge_index_temp = sp.coo_matrix(adj)
            indices = np.vstack((edge_index_temp.row, edge_index_temp.col))
            edge_index_A = torch.LongTensor(indices) 
            x = self.get_x_feature()
            data = Data(x=x, edge_index=edge_index_A)
            dataset.append(data)
        return dataset


def sparse_to_tuple(sparse_mx):
    if not sp.isspmatrix_coo(sparse_mx):
        sparse_mx = sparse_mx.tocoo()
    coords = np.vstack((sparse_mx.row, sparse_mx.col)).transpose()
    values = sparse_mx.data
    shape = sparse_mx.shape
    return coords, values, shape

def preprocess_graph(adj):
    adj = sp.coo_matrix(adj)
    adj_ = adj + sp.eye(adj.shape[0])
    rowsum = np.array(adj_.sum(1))
    degree_mat_inv_sqrt = sp.diags(np.power(rowsum, -0.5).flatten())
    adj_normalized = adj_.dot(degree_mat_inv_sqrt).transpose().dot(degree_mat_inv_sqrt).tocoo()
    
    return sparse_to_tuple(adj_normalized)

from os import walk

def get_filename(mypath):
    f = []
    for (dirpath, dirnames, filenames) in walk(mypath):
        f.extend(filenames)
        break
    return f

# %%
n_node = 10
temp = np.zeros((2, n_node * n_node))
for i in range(n_node):
    for j in range(n_node):
        temp[0, j + n_node*i] = j
for i in range(n_node):
    for j in range(n_node):
        temp[1, j + n_node*i] = i
edge_index = temp

# %%
simu_graph = SimuData(n_graph=30, p=0.8)
dataset = simu_graph.graph_dataset()
n_node = simu_graph.n_node

# %%
out_channels = 2
n_node = 10
num_features = n_node

VGAE_Encoder = Encoder(num_features, out_channels)
model = VGAE(VGAE_Encoder)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
epochs = 500

for epoch in range(epochs):
    loss_total = 0
    optimizer.zero_grad()
    
    for i in range(len(dataset)):
        train_data, val_data, test_data = transform(dataset[i])
        z = model.encode(train_data.x, train_data.edge_index)
        loss =10 * model.recon_loss(z, train_data.edge_index)
        loss = loss + (1 /num_features) * model.kl_loss()
        loss_total += loss

    loss_avg = loss_total/len(dataset)
    loss_avg.backward()
    optimizer.step()
    print(str(epoch)+str(loss_avg))
# Out:
# 0tensor(18.2349, grad_fn=<DivBackward0>)
# 1tensor(19.2225, grad_fn=<DivBackward0>)
# 2tensor(17.7096, grad_fn=<DivBackward0>)
# 3tensor(20.4868, grad_fn=<DivBackward0>)
# 4tensor(18.2978, grad_fn=<DivBackward0>)
# 5tensor(16.3650, grad_fn=<DivBackward0>)
# 6tensor(16.6484, grad_fn=<DivBackward0>)
# 7tensor(16.8378, grad_fn=<DivBackward0>)
# 8tensor(17.3037, grad_fn=<DivBackward0>)
# 9tensor(16.2549, grad_fn=<DivBackward0>)
# 10tensor(18.1060, grad_fn=<DivBackward0>)
# 11tensor(17.8888, grad_fn=<DivBackward0>)
# 12tensor(16.2314, grad_fn=<DivBackward0>)
# 13tensor(15.6486, grad_fn=<DivBackward0>)
# 14tensor(17.0268, grad_fn=<DivBackward0>)
# 15tensor(16.0422, grad_fn=<DivBackward0>)
# 16tensor(15.2463, grad_fn=<DivBackward0>)
# 17tensor(16.3447, grad_fn=<DivBackward0>)
# 18tensor(16.2783, grad_fn=<DivBackward0>)
# 19tensor(16.2250, grad_fn=<DivBackward0>)
# 20tensor(16.7389, grad_fn=<DivBackward0>)
# 21tensor(15.2872, grad_fn=<DivBackward0>)
# 22tensor(15.5638, grad_fn=<DivBackward0>)
# 23tensor(15.7426, grad_fn=<DivBackward0>)
# 24tensor(14.7551, grad_fn=<DivBackward0>)
# 25tensor(14.8942, grad_fn=<DivBackward0>)
# 26tensor(15.5688, grad_fn=<DivBackward0>)
# 27tensor(15.0681, grad_fn=<DivBackward0>)
# 28tensor(14.5946, grad_fn=<DivBackward0>)
# 29tensor(15.1901, grad_fn=<DivBackward0>)
# 30tensor(14.8053, grad_fn=<DivBackward0>)
# 31tensor(15.8765, grad_fn=<DivBackward0>)
# 32tensor(14.6349, grad_fn=<DivBackward0>)
# 33tensor(15.0551, grad_fn=<DivBackward0>)
# 34tensor(15.1092, grad_fn=<DivBackward0>)
# 35tensor(14.9545, grad_fn=<DivBackward0>)
# 36tensor(14.6454, grad_fn=<DivBackward0>)
# 37tensor(14.8030, grad_fn=<DivBackward0>)
# 38tensor(14.8184, grad_fn=<DivBackward0>)
# 39tensor(14.7509, grad_fn=<DivBackward0>)
# 40tensor(14.8014, grad_fn=<DivBackward0>)
# 41tensor(14.3018, grad_fn=<DivBackward0>)
# 42tensor(14.7279, grad_fn=<DivBackward0>)
# 43tensor(14.1577, grad_fn=<DivBackward0>)
# 44tensor(14.2952, grad_fn=<DivBackward0>)
# 45tensor(14.0231, grad_fn=<DivBackward0>)
# 46tensor(14.5097, grad_fn=<DivBackward0>)
# 47tensor(14.2633, grad_fn=<DivBackward0>)
# 48tensor(14.0239, grad_fn=<DivBackward0>)
# 49tensor(14.2125, grad_fn=<DivBackward0>)
# 50tensor(14.5976, grad_fn=<DivBackward0>)
# 51tensor(14.2610, grad_fn=<DivBackward0>)
# 52tensor(14.1740, grad_fn=<DivBackward0>)
# 53tensor(14.3453, grad_fn=<DivBackward0>)
# 54tensor(13.9617, grad_fn=<DivBackward0>)
# 55tensor(14.1873, grad_fn=<DivBackward0>)
# 56tensor(13.8592, grad_fn=<DivBackward0>)
# 57tensor(13.9926, grad_fn=<DivBackward0>)
# 58tensor(13.9629, grad_fn=<DivBackward0>)
# 59tensor(13.9459, grad_fn=<DivBackward0>)
# 60tensor(14.1407, grad_fn=<DivBackward0>)
# 61tensor(14.1096, grad_fn=<DivBackward0>)
# 62tensor(13.9980, grad_fn=<DivBackward0>)
# 63tensor(13.9930, grad_fn=<DivBackward0>)
# 64tensor(14.0307, grad_fn=<DivBackward0>)
# 65tensor(13.9764, grad_fn=<DivBackward0>)
# 66tensor(13.9451, grad_fn=<DivBackward0>)
# 67tensor(13.9456, grad_fn=<DivBackward0>)
# 68tensor(13.9380, grad_fn=<DivBackward0>)
# 69tensor(13.9887, grad_fn=<DivBackward0>)
# 70tensor(13.8835, grad_fn=<DivBackward0>)
# 71tensor(13.8047, grad_fn=<DivBackward0>)
# 72tensor(13.7843, grad_fn=<DivBackward0>)
# 73tensor(13.7278, grad_fn=<DivBackward0>)
# 74tensor(13.7313, grad_fn=<DivBackward0>)
# 75tensor(13.6749, grad_fn=<DivBackward0>)
# 76tensor(13.4302, grad_fn=<DivBackward0>)
# 77tensor(13.5025, grad_fn=<DivBackward0>)
# 78tensor(13.3855, grad_fn=<DivBackward0>)
# 79tensor(13.2670, grad_fn=<DivBackward0>)
# 80tensor(13.0368, grad_fn=<DivBackward0>)
# 81tensor(13.3084, grad_fn=<DivBackward0>)
# 82tensor(12.8581, grad_fn=<DivBackward0>)
# 83tensor(13.0047, grad_fn=<DivBackward0>)
# 84tensor(12.5485, grad_fn=<DivBackward0>)
# 85tensor(12.5313, grad_fn=<DivBackward0>)
# 86tensor(12.4092, grad_fn=<DivBackward0>)
# 87tensor(12.2965, grad_fn=<DivBackward0>)
# 88tensor(11.9588, grad_fn=<DivBackward0>)
# 89tensor(11.7624, grad_fn=<DivBackward0>)
# 90tensor(11.7582, grad_fn=<DivBackward0>)
# 91tensor(11.3577, grad_fn=<DivBackward0>)
# 92tensor(11.4190, grad_fn=<DivBackward0>)
# 93tensor(11.3819, grad_fn=<DivBackward0>)
# 94tensor(10.9081, grad_fn=<DivBackward0>)
# 95tensor(10.9759, grad_fn=<DivBackward0>)
# 96tensor(10.8005, grad_fn=<DivBackward0>)
# 97tensor(10.6120, grad_fn=<DivBackward0>)
# 98tensor(10.1636, grad_fn=<DivBackward0>)
# 99tensor(10.8184, grad_fn=<DivBackward0>)
# 100tensor(10.5343, grad_fn=<DivBackward0>)
# 101tensor(10.1467, grad_fn=<DivBackward0>)
# 102tensor(10.4888, grad_fn=<DivBackward0>)
# 103tensor(10.3568, grad_fn=<DivBackward0>)
# 104tensor(10.0400, grad_fn=<DivBackward0>)
# 105tensor(10.8600, grad_fn=<DivBackward0>)
# 106tensor(9.5851, grad_fn=<DivBackward0>)
# 107tensor(10.4170, grad_fn=<DivBackward0>)
# 108tensor(10.2048, grad_fn=<DivBackward0>)
# 109tensor(10.2628, grad_fn=<DivBackward0>)
# 110tensor(9.8409, grad_fn=<DivBackward0>)
# 111tensor(10.0983, grad_fn=<DivBackward0>)
# 112tensor(9.8824, grad_fn=<DivBackward0>)
# 113tensor(10.0893, grad_fn=<DivBackward0>)
# 114tensor(10.0067, grad_fn=<DivBackward0>)
# 115tensor(9.7708, grad_fn=<DivBackward0>)
# 116tensor(9.8766, grad_fn=<DivBackward0>)
# 117tensor(9.6235, grad_fn=<DivBackward0>)
# 118tensor(9.7430, grad_fn=<DivBackward0>)
# 119tensor(9.3311, grad_fn=<DivBackward0>)
# 120tensor(9.7891, grad_fn=<DivBackward0>)
# 121tensor(9.2347, grad_fn=<DivBackward0>)
# 122tensor(9.6922, grad_fn=<DivBackward0>)
# 123tensor(9.3565, grad_fn=<DivBackward0>)
# 124tensor(9.2706, grad_fn=<DivBackward0>)
# 125tensor(8.9365, grad_fn=<DivBackward0>)
# 126tensor(9.4179, grad_fn=<DivBackward0>)
# 127tensor(9.3566, grad_fn=<DivBackward0>)
# 128tensor(9.0402, grad_fn=<DivBackward0>)
# 129tensor(9.4754, grad_fn=<DivBackward0>)
# 130tensor(9.6767, grad_fn=<DivBackward0>)
# 131tensor(9.2100, grad_fn=<DivBackward0>)
# 132tensor(9.1681, grad_fn=<DivBackward0>)
# 133tensor(9.4846, grad_fn=<DivBackward0>)
# 134tensor(9.1946, grad_fn=<DivBackward0>)
# 135tensor(8.7491, grad_fn=<DivBackward0>)
# 136tensor(8.5573, grad_fn=<DivBackward0>)
# 137tensor(9.0007, grad_fn=<DivBackward0>)
# 138tensor(9.1242, grad_fn=<DivBackward0>)
# 139tensor(8.9921, grad_fn=<DivBackward0>)
# 140tensor(8.7344, grad_fn=<DivBackward0>)
# 141tensor(8.6846, grad_fn=<DivBackward0>)
# 142tensor(8.6367, grad_fn=<DivBackward0>)
# 143tensor(9.0279, grad_fn=<DivBackward0>)
# 144tensor(8.4507, grad_fn=<DivBackward0>)
# 145tensor(8.7671, grad_fn=<DivBackward0>)
# 146tensor(8.9188, grad_fn=<DivBackward0>)
# 147tensor(8.7266, grad_fn=<DivBackward0>)
# 148tensor(8.5064, grad_fn=<DivBackward0>)
# 149tensor(8.1969, grad_fn=<DivBackward0>)
# 150tensor(8.1218, grad_fn=<DivBackward0>)
# 151tensor(8.0984, grad_fn=<DivBackward0>)
# 152tensor(8.4001, grad_fn=<DivBackward0>)
# 153tensor(7.8297, grad_fn=<DivBackward0>)
# 154tensor(8.4606, grad_fn=<DivBackward0>)
# 155tensor(8.1011, grad_fn=<DivBackward0>)
# 156tensor(8.2052, grad_fn=<DivBackward0>)
# 157tensor(7.9394, grad_fn=<DivBackward0>)
# 158tensor(8.4309, grad_fn=<DivBackward0>)
# 159tensor(8.0100, grad_fn=<DivBackward0>)
# 160tensor(7.8167, grad_fn=<DivBackward0>)
# 161tensor(8.3244, grad_fn=<DivBackward0>)
# 162tensor(8.0060, grad_fn=<DivBackward0>)
# 163tensor(8.0610, grad_fn=<DivBackward0>)
# 164tensor(8.0039, grad_fn=<DivBackward0>)
# 165tensor(7.9885, grad_fn=<DivBackward0>)
# 166tensor(8.3303, grad_fn=<DivBackward0>)
# 167tensor(8.1215, grad_fn=<DivBackward0>)
# 168tensor(7.8182, grad_fn=<DivBackward0>)
# 169tensor(8.3570, grad_fn=<DivBackward0>)
# 170tensor(8.0669, grad_fn=<DivBackward0>)
# 171tensor(7.7165, grad_fn=<DivBackward0>)
# 172tensor(8.1291, grad_fn=<DivBackward0>)
# 173tensor(8.3268, grad_fn=<DivBackward0>)
# 174tensor(8.1141, grad_fn=<DivBackward0>)
# 175tensor(8.1641, grad_fn=<DivBackward0>)
# 176tensor(8.3719, grad_fn=<DivBackward0>)
# 177tensor(8.0838, grad_fn=<DivBackward0>)
# 178tensor(7.9220, grad_fn=<DivBackward0>)
# 179tensor(8.2132, grad_fn=<DivBackward0>)
# 180tensor(7.9131, grad_fn=<DivBackward0>)
# 181tensor(8.0702, grad_fn=<DivBackward0>)
# 182tensor(8.0224, grad_fn=<DivBackward0>)
# 183tensor(7.7950, grad_fn=<DivBackward0>)
# 184tensor(7.8784, grad_fn=<DivBackward0>)
# 185tensor(7.7888, grad_fn=<DivBackward0>)
# 186tensor(8.1694, grad_fn=<DivBackward0>)
# 187tensor(7.8569, grad_fn=<DivBackward0>)
# 188tensor(7.6959, grad_fn=<DivBackward0>)
# 189tensor(8.3221, grad_fn=<DivBackward0>)
# 190tensor(7.8809, grad_fn=<DivBackward0>)
# 191tensor(8.0593, grad_fn=<DivBackward0>)
# 192tensor(7.8547, grad_fn=<DivBackward0>)
# 193tensor(7.7713, grad_fn=<DivBackward0>)
# 194tensor(8.1607, grad_fn=<DivBackward0>)
# 195tensor(8.2661, grad_fn=<DivBackward0>)
# 196tensor(8.3131, grad_fn=<DivBackward0>)
# 197tensor(7.7049, grad_fn=<DivBackward0>)
# 198tensor(7.9410, grad_fn=<DivBackward0>)
# 199tensor(7.6724, grad_fn=<DivBackward0>)
# 200tensor(7.7518, grad_fn=<DivBackward0>)
# 201tensor(7.8626, grad_fn=<DivBackward0>)
# 202tensor(7.8115, grad_fn=<DivBackward0>)
# 203tensor(7.6530, grad_fn=<DivBackward0>)
# 204tensor(8.1359, grad_fn=<DivBackward0>)
# 205tensor(8.2877, grad_fn=<DivBackward0>)
# 206tensor(7.6612, grad_fn=<DivBackward0>)
# 207tensor(7.5318, grad_fn=<DivBackward0>)
# 208tensor(7.5803, grad_fn=<DivBackward0>)
# 209tensor(7.7602, grad_fn=<DivBackward0>)
# 210tensor(8.1067, grad_fn=<DivBackward0>)
# 211tensor(7.6610, grad_fn=<DivBackward0>)
# 212tensor(7.6973, grad_fn=<DivBackward0>)
# 213tensor(7.6418, grad_fn=<DivBackward0>)
# 214tensor(7.7724, grad_fn=<DivBackward0>)
# 215tensor(8.0040, grad_fn=<DivBackward0>)
# 216tensor(8.0461, grad_fn=<DivBackward0>)
# 217tensor(7.6453, grad_fn=<DivBackward0>)
# 218tensor(7.4210, grad_fn=<DivBackward0>)
# 219tensor(7.6778, grad_fn=<DivBackward0>)
# 220tensor(7.7504, grad_fn=<DivBackward0>)
# 221tensor(7.7947, grad_fn=<DivBackward0>)
# 222tensor(7.8615, grad_fn=<DivBackward0>)
# 223tensor(7.5952, grad_fn=<DivBackward0>)
# 224tensor(7.5054, grad_fn=<DivBackward0>)
# 225tensor(7.8204, grad_fn=<DivBackward0>)
# 226tensor(7.7060, grad_fn=<DivBackward0>)
# 227tensor(8.1332, grad_fn=<DivBackward0>)
# 228tensor(7.5901, grad_fn=<DivBackward0>)
# 229tensor(7.8819, grad_fn=<DivBackward0>)
# 230tensor(7.7478, grad_fn=<DivBackward0>)
# 231tensor(7.9619, grad_fn=<DivBackward0>)
# 232tensor(7.7209, grad_fn=<DivBackward0>)
# 233tensor(7.2380, grad_fn=<DivBackward0>)
# 234tensor(7.8877, grad_fn=<DivBackward0>)
# 235tensor(7.6070, grad_fn=<DivBackward0>)
# 236tensor(7.5359, grad_fn=<DivBackward0>)
# 237tensor(8.0026, grad_fn=<DivBackward0>)
# 238tensor(7.8881, grad_fn=<DivBackward0>)
# 239tensor(7.7351, grad_fn=<DivBackward0>)
# 240tensor(7.5624, grad_fn=<DivBackward0>)
# 241tensor(7.9665, grad_fn=<DivBackward0>)
# 242tensor(8.1416, grad_fn=<DivBackward0>)
# 243tensor(7.7565, grad_fn=<DivBackward0>)
# 244tensor(7.5436, grad_fn=<DivBackward0>)
# 245tensor(7.8356, grad_fn=<DivBackward0>)
# 246tensor(7.5883, grad_fn=<DivBackward0>)
# 247tensor(7.9093, grad_fn=<DivBackward0>)
# 248tensor(7.4211, grad_fn=<DivBackward0>)
# 249tensor(7.5208, grad_fn=<DivBackward0>)
# 250tensor(7.8054, grad_fn=<DivBackward0>)
# 251tensor(7.7212, grad_fn=<DivBackward0>)
# 252tensor(7.9065, grad_fn=<DivBackward0>)
# 253tensor(7.6851, grad_fn=<DivBackward0>)
# 254tensor(7.0796, grad_fn=<DivBackward0>)
# 255tensor(7.6050, grad_fn=<DivBackward0>)
# 256tensor(7.8438, grad_fn=<DivBackward0>)
# 257tensor(7.3689, grad_fn=<DivBackward0>)
# 258tensor(7.4844, grad_fn=<DivBackward0>)
# 259tensor(7.5640, grad_fn=<DivBackward0>)
# 260tensor(7.8716, grad_fn=<DivBackward0>)
# 261tensor(7.2469, grad_fn=<DivBackward0>)
# 262tensor(7.4637, grad_fn=<DivBackward0>)
# 263tensor(7.3481, grad_fn=<DivBackward0>)
# 264tensor(7.7373, grad_fn=<DivBackward0>)
# 265tensor(7.9200, grad_fn=<DivBackward0>)
# 266tensor(7.9581, grad_fn=<DivBackward0>)
# 267tensor(7.3831, grad_fn=<DivBackward0>)
# 268tensor(7.3406, grad_fn=<DivBackward0>)
# 269tensor(7.5168, grad_fn=<DivBackward0>)
# 270tensor(7.4021, grad_fn=<DivBackward0>)
# 271tensor(7.5850, grad_fn=<DivBackward0>)
# 272tensor(7.3502, grad_fn=<DivBackward0>)
# 273tensor(7.6568, grad_fn=<DivBackward0>)
# 274tensor(7.3014, grad_fn=<DivBackward0>)
# 275tensor(7.6902, grad_fn=<DivBackward0>)
# 276tensor(7.9624, grad_fn=<DivBackward0>)
# 277tensor(7.8079, grad_fn=<DivBackward0>)
# 278tensor(7.9615, grad_fn=<DivBackward0>)
# 279tensor(7.5741, grad_fn=<DivBackward0>)
# 280tensor(7.7552, grad_fn=<DivBackward0>)
# 281tensor(7.4436, grad_fn=<DivBackward0>)
# 282tensor(7.7283, grad_fn=<DivBackward0>)
# 283tensor(7.6619, grad_fn=<DivBackward0>)
# 284tensor(7.7857, grad_fn=<DivBackward0>)
# 285tensor(7.2208, grad_fn=<DivBackward0>)
# 286tensor(7.8229, grad_fn=<DivBackward0>)
# 287tensor(7.8155, grad_fn=<DivBackward0>)
# 288tensor(7.7753, grad_fn=<DivBackward0>)
# 289tensor(7.6113, grad_fn=<DivBackward0>)
# 290tensor(7.9382, grad_fn=<DivBackward0>)
# 291tensor(7.7229, grad_fn=<DivBackward0>)
# 292tensor(8.2418, grad_fn=<DivBackward0>)
# 293tensor(7.1311, grad_fn=<DivBackward0>)
# 294tensor(7.9202, grad_fn=<DivBackward0>)
# 295tensor(7.6604, grad_fn=<DivBackward0>)
# 296tensor(7.4302, grad_fn=<DivBackward0>)
# 297tensor(8.2090, grad_fn=<DivBackward0>)
# 298tensor(7.5822, grad_fn=<DivBackward0>)
# 299tensor(7.5905, grad_fn=<DivBackward0>)
# 300tensor(7.3382, grad_fn=<DivBackward0>)
# 301tensor(7.6741, grad_fn=<DivBackward0>)
# 302tensor(7.6581, grad_fn=<DivBackward0>)
# 303tensor(7.1984, grad_fn=<DivBackward0>)
# 304tensor(8.0291, grad_fn=<DivBackward0>)
# 305tensor(8.1151, grad_fn=<DivBackward0>)
# 306tensor(8.0818, grad_fn=<DivBackward0>)
# 307tensor(7.5171, grad_fn=<DivBackward0>)
# 308tensor(7.8143, grad_fn=<DivBackward0>)
# 309tensor(7.7219, grad_fn=<DivBackward0>)
# 310tensor(7.8979, grad_fn=<DivBackward0>)
# 311tensor(7.3271, grad_fn=<DivBackward0>)
# 312tensor(7.4274, grad_fn=<DivBackward0>)
# 313tensor(7.9194, grad_fn=<DivBackward0>)
# 314tensor(7.4553, grad_fn=<DivBackward0>)
# 315tensor(7.9928, grad_fn=<DivBackward0>)
# 316tensor(7.7375, grad_fn=<DivBackward0>)
# 317tensor(7.6824, grad_fn=<DivBackward0>)
# 318tensor(7.6811, grad_fn=<DivBackward0>)
# 319tensor(7.4133, grad_fn=<DivBackward0>)
# 320tensor(7.2119, grad_fn=<DivBackward0>)
# 321tensor(7.6701, grad_fn=<DivBackward0>)
# 322tensor(7.7987, grad_fn=<DivBackward0>)
# 323tensor(7.5336, grad_fn=<DivBackward0>)
# 324tensor(7.1293, grad_fn=<DivBackward0>)
# 325tensor(7.7181, grad_fn=<DivBackward0>)
# 326tensor(7.2129, grad_fn=<DivBackward0>)
# 327tensor(7.7874, grad_fn=<DivBackward0>)
# 328tensor(8.0239, grad_fn=<DivBackward0>)
# 329tensor(7.5266, grad_fn=<DivBackward0>)
# 330tensor(7.6790, grad_fn=<DivBackward0>)
# 331tensor(7.3862, grad_fn=<DivBackward0>)
# 332tensor(7.7041, grad_fn=<DivBackward0>)
# 333tensor(7.1423, grad_fn=<DivBackward0>)
# 334tensor(7.5990, grad_fn=<DivBackward0>)
# 335tensor(7.5986, grad_fn=<DivBackward0>)
# 336tensor(7.6703, grad_fn=<DivBackward0>)
# 337tensor(7.4638, grad_fn=<DivBackward0>)
# 338tensor(8.0628, grad_fn=<DivBackward0>)
# 339tensor(7.4936, grad_fn=<DivBackward0>)
# 340tensor(7.3145, grad_fn=<DivBackward0>)
# 341tensor(7.1399, grad_fn=<DivBackward0>)
# 342tensor(7.7895, grad_fn=<DivBackward0>)
# 343tensor(7.6647, grad_fn=<DivBackward0>)
# 344tensor(7.3965, grad_fn=<DivBackward0>)
# 345tensor(7.4764, grad_fn=<DivBackward0>)
# 346tensor(7.6004, grad_fn=<DivBackward0>)
# 347tensor(7.5771, grad_fn=<DivBackward0>)
# 348tensor(7.6921, grad_fn=<DivBackward0>)
# 349tensor(7.8201, grad_fn=<DivBackward0>)
# 350tensor(7.6183, grad_fn=<DivBackward0>)
# 351tensor(7.4257, grad_fn=<DivBackward0>)
# 352tensor(7.2568, grad_fn=<DivBackward0>)
# 353tensor(7.5126, grad_fn=<DivBackward0>)
# 354tensor(7.4532, grad_fn=<DivBackward0>)
# 355tensor(7.5915, grad_fn=<DivBackward0>)
# 356tensor(7.8765, grad_fn=<DivBackward0>)
# 357tensor(7.6482, grad_fn=<DivBackward0>)
# 358tensor(7.7072, grad_fn=<DivBackward0>)
# 359tensor(7.2819, grad_fn=<DivBackward0>)
# 360tensor(7.2133, grad_fn=<DivBackward0>)
# 361tensor(7.5263, grad_fn=<DivBackward0>)
# 362tensor(7.9653, grad_fn=<DivBackward0>)
# 363tensor(7.4764, grad_fn=<DivBackward0>)
# 364tensor(8.3965, grad_fn=<DivBackward0>)
# 365tensor(7.5940, grad_fn=<DivBackward0>)
# 366tensor(7.7504, grad_fn=<DivBackward0>)
# 367tensor(7.7690, grad_fn=<DivBackward0>)
# 368tensor(7.8418, grad_fn=<DivBackward0>)
# 369tensor(7.5271, grad_fn=<DivBackward0>)
# 370tensor(7.9279, grad_fn=<DivBackward0>)
# 371tensor(7.6649, grad_fn=<DivBackward0>)
# 372tensor(7.6920, grad_fn=<DivBackward0>)
# 373tensor(7.3963, grad_fn=<DivBackward0>)
# 374tensor(7.7768, grad_fn=<DivBackward0>)
# 375tensor(7.7749, grad_fn=<DivBackward0>)
# 376tensor(7.7365, grad_fn=<DivBackward0>)
# 377tensor(7.7501, grad_fn=<DivBackward0>)
# 378tensor(8.0526, grad_fn=<DivBackward0>)
# 379tensor(7.2644, grad_fn=<DivBackward0>)
# 380tensor(7.5914, grad_fn=<DivBackward0>)
# 381tensor(7.4139, grad_fn=<DivBackward0>)
# 382tensor(7.6061, grad_fn=<DivBackward0>)
# 383tensor(7.6224, grad_fn=<DivBackward0>)
# 384tensor(7.6909, grad_fn=<DivBackward0>)
# 385tensor(7.4873, grad_fn=<DivBackward0>)
# 386tensor(7.8004, grad_fn=<DivBackward0>)
# 387tensor(8.1549, grad_fn=<DivBackward0>)
# 388tensor(7.5798, grad_fn=<DivBackward0>)
# 389tensor(7.5947, grad_fn=<DivBackward0>)
# 390tensor(7.5143, grad_fn=<DivBackward0>)
# 391tensor(7.6167, grad_fn=<DivBackward0>)
# 392tensor(8.0002, grad_fn=<DivBackward0>)
# 393tensor(8.1579, grad_fn=<DivBackward0>)
# 394tensor(7.5007, grad_fn=<DivBackward0>)
# 395tensor(7.4140, grad_fn=<DivBackward0>)
# 396tensor(7.4922, grad_fn=<DivBackward0>)
# 397tensor(7.8312, grad_fn=<DivBackward0>)
# 398tensor(7.4826, grad_fn=<DivBackward0>)
# 399tensor(7.6702, grad_fn=<DivBackward0>)
# 400tensor(7.8861, grad_fn=<DivBackward0>)
# 401tensor(7.3441, grad_fn=<DivBackward0>)
# 402tensor(7.7189, grad_fn=<DivBackward0>)
# 403tensor(7.3601, grad_fn=<DivBackward0>)
# 404tensor(7.8934, grad_fn=<DivBackward0>)
# 405tensor(7.5855, grad_fn=<DivBackward0>)
# 406tensor(7.5386, grad_fn=<DivBackward0>)
# 407tensor(7.4358, grad_fn=<DivBackward0>)
# 408tensor(7.6394, grad_fn=<DivBackward0>)
# 409tensor(7.5607, grad_fn=<DivBackward0>)
# 410tensor(7.3312, grad_fn=<DivBackward0>)
# 411tensor(7.4695, grad_fn=<DivBackward0>)
# 412tensor(7.9444, grad_fn=<DivBackward0>)
# 413tensor(8.4413, grad_fn=<DivBackward0>)
# 414tensor(7.8410, grad_fn=<DivBackward0>)
# 415tensor(7.4256, grad_fn=<DivBackward0>)
# 416tensor(8.1586, grad_fn=<DivBackward0>)
# 417tensor(7.6089, grad_fn=<DivBackward0>)
# 418tensor(7.8412, grad_fn=<DivBackward0>)
# 419tensor(7.3878, grad_fn=<DivBackward0>)
# 420tensor(8.5018, grad_fn=<DivBackward0>)
# 421tensor(7.9551, grad_fn=<DivBackward0>)
# 422tensor(7.8717, grad_fn=<DivBackward0>)
# 423tensor(7.5767, grad_fn=<DivBackward0>)
# 424tensor(7.5562, grad_fn=<DivBackward0>)
# 425tensor(7.4886, grad_fn=<DivBackward0>)
# 426tensor(7.7888, grad_fn=<DivBackward0>)
# 427tensor(7.6070, grad_fn=<DivBackward0>)
# 428tensor(7.4456, grad_fn=<DivBackward0>)
# 429tensor(8.0715, grad_fn=<DivBackward0>)
# 430tensor(7.8647, grad_fn=<DivBackward0>)
# 431tensor(7.0936, grad_fn=<DivBackward0>)
# 432tensor(7.6597, grad_fn=<DivBackward0>)
# 433tensor(7.7807, grad_fn=<DivBackward0>)
# 434tensor(7.7921, grad_fn=<DivBackward0>)
# 435tensor(8.0282, grad_fn=<DivBackward0>)
# 436tensor(7.6973, grad_fn=<DivBackward0>)
# 437tensor(8.2877, grad_fn=<DivBackward0>)
# 438tensor(8.0798, grad_fn=<DivBackward0>)
# 439tensor(7.4137, grad_fn=<DivBackward0>)
# 440tensor(7.9313, grad_fn=<DivBackward0>)
# 441tensor(7.4599, grad_fn=<DivBackward0>)
# 442tensor(8.0571, grad_fn=<DivBackward0>)
# 443tensor(7.5059, grad_fn=<DivBackward0>)
# 444tensor(7.6835, grad_fn=<DivBackward0>)
# 445tensor(7.2240, grad_fn=<DivBackward0>)
# 446tensor(7.8892, grad_fn=<DivBackward0>)
# 447tensor(7.5791, grad_fn=<DivBackward0>)
# 448tensor(7.4260, grad_fn=<DivBackward0>)
# 449tensor(7.7347, grad_fn=<DivBackward0>)
# 450tensor(7.2536, grad_fn=<DivBackward0>)
# 451tensor(8.1470, grad_fn=<DivBackward0>)
# 452tensor(7.4519, grad_fn=<DivBackward0>)
# 453tensor(7.5926, grad_fn=<DivBackward0>)
# 454tensor(7.6257, grad_fn=<DivBackward0>)
# 455tensor(7.7033, grad_fn=<DivBackward0>)
# 456tensor(8.0712, grad_fn=<DivBackward0>)
# 457tensor(7.6109, grad_fn=<DivBackward0>)
# 458tensor(7.7148, grad_fn=<DivBackward0>)
# 459tensor(7.9347, grad_fn=<DivBackward0>)
# 460tensor(7.7330, grad_fn=<DivBackward0>)
# 461tensor(7.7499, grad_fn=<DivBackward0>)
# 462tensor(8.1915, grad_fn=<DivBackward0>)
# 463tensor(7.2291, grad_fn=<DivBackward0>)
# 464tensor(7.7165, grad_fn=<DivBackward0>)
# 465tensor(7.4148, grad_fn=<DivBackward0>)
# 466tensor(7.7562, grad_fn=<DivBackward0>)
# 467tensor(7.9161, grad_fn=<DivBackward0>)
# 468tensor(7.6963, grad_fn=<DivBackward0>)
# 469tensor(7.5209, grad_fn=<DivBackward0>)
# 470tensor(7.9014, grad_fn=<DivBackward0>)
# 471tensor(7.6452, grad_fn=<DivBackward0>)
# 472tensor(7.3660, grad_fn=<DivBackward0>)
# 473tensor(7.5826, grad_fn=<DivBackward0>)
# 474tensor(7.6329, grad_fn=<DivBackward0>)
# 475tensor(7.4396, grad_fn=<DivBackward0>)
# 476tensor(7.6404, grad_fn=<DivBackward0>)
# 477tensor(7.6341, grad_fn=<DivBackward0>)
# 478tensor(7.5052, grad_fn=<DivBackward0>)
# 479tensor(7.6948, grad_fn=<DivBackward0>)
# 480tensor(7.8014, grad_fn=<DivBackward0>)
# 481tensor(7.2425, grad_fn=<DivBackward0>)
# 482tensor(7.9242, grad_fn=<DivBackward0>)
# 483tensor(7.7578, grad_fn=<DivBackward0>)
# 484tensor(7.4734, grad_fn=<DivBackward0>)
# 485tensor(7.6360, grad_fn=<DivBackward0>)
# 486tensor(7.7842, grad_fn=<DivBackward0>)
# 487tensor(7.8459, grad_fn=<DivBackward0>)
# 488tensor(8.3940, grad_fn=<DivBackward0>)
# 489tensor(7.2632, grad_fn=<DivBackward0>)
# 490tensor(7.3801, grad_fn=<DivBackward0>)
# 491tensor(8.0801, grad_fn=<DivBackward0>)
# 492tensor(8.1556, grad_fn=<DivBackward0>)
# 493tensor(7.6053, grad_fn=<DivBackward0>)
# 494tensor(7.8107, grad_fn=<DivBackward0>)
# 495tensor(7.8135, grad_fn=<DivBackward0>)
# 496tensor(7.5727, grad_fn=<DivBackward0>)
# 497tensor(8.0491, grad_fn=<DivBackward0>)
# 498tensor(7.2901, grad_fn=<DivBackward0>)
# 499tensor(8.1140, grad_fn=<DivBackward0>)

# %%
os.chdir('C:\\Users\\Ji Qi\\Documents\\GitHub\\ST-Aim3')
os.getcwd()
PATH = 'vgae_model_for_simulation_0.8.pth'
torch.save(model, PATH)

model = torch.load(PATH)
model.eval()
# Out:
# VGAE(
#   (encoder): Encoder(
#     (conv1): GCNConv(10, 4)
#     (conv_mu): GCNConv(4, 2)
#     (conv_logstd): GCNConv(4, 2)
#   )
#   (decoder): InnerProductDecoder()
# )

# %%
for i in range(len(dataset)):
    train_data = dataset[i]
    print(VGAE_Encoder(train_data.x, train_data.edge_index))
# Out:
# (tensor([[-1.0637, -1.6674],
#         [-0.7477, -1.3852],
#         [-0.7477, -1.3852],
#         [-1.0637, -1.6674],
#         [-0.5346, -1.1948],
#         [ 1.3675,  0.5042],
#         [-0.0950,  0.7783],
#         [-0.3018,  0.9647],
#         [-0.1505,  0.7758],
#         [ 1.0173,  0.1914]], grad_fn=<AddBackward0>), tensor([[-1.9785, -2.3820],
#         [-1.8128, -2.1893],
#         [-1.8128, -2.1893],
#         [-1.9785, -2.3820],
#         [-1.7010, -2.0593],
#         [-0.7035, -0.8993],
#         [-1.6955, -2.0599],
#         [-1.8568, -2.2492],
#         [-1.7314, -2.1018],
#         [-0.8872, -1.1129]], grad_fn=<AddBackward0>))
# (tensor([[-0.9406, -1.5575],
#         [-0.9406, -1.5575],
#         [-0.9406, -1.5575],
#         [-0.6878, -1.3317],
#         [-0.6833, -1.3276],
#         [ 1.3675,  0.5042],
#         [-0.0950,  0.7783],
#         [-0.3018,  0.9647],
#         [-0.1505,  0.7758],
#         [ 1.0173,  0.1914]], grad_fn=<AddBackward0>), tensor([[-1.9140, -2.3069],
#         [-1.9140, -2.3069],
#         [-1.9140, -2.3069],
#         [-1.7814, -2.1528],
#         [-1.7790, -2.1500],
#         [-0.7035, -0.8993],
#         [-1.6955, -2.0599],
#         [-1.8568, -2.2492],
#         [-1.7314, -2.1018],
#         [-0.8872, -1.1129]], grad_fn=<AddBackward0>))
# (tensor([[-0.6815, -1.3260],
#         [-0.9430, -1.5597],
#         [-0.9430, -1.5597],
#         [-0.6910, -1.3345],
#         [-0.9430, -1.5597],
#         [ 1.3675,  0.5042],
#         [-0.0950,  0.7783],
#         [-0.3018,  0.9647],
#         [-0.1505,  0.7758],
#         [ 1.0173,  0.1914]], grad_fn=<AddBackward0>), tensor([[-1.7781, -2.1489],
#         [-1.9152, -2.3084],
#         [-1.9152, -2.3084],
#         [-1.7831, -2.1547],
#         [-1.9152, -2.3084],
#         [-0.7035, -0.8993],
#         [-1.6955, -2.0599],
#         [-1.8568, -2.2492],
#         [-1.7314, -2.1018],
#         [-0.8872, -1.1129]], grad_fn=<AddBackward0>))
# (tensor([[-0.9406, -1.5575],
#         [-0.9406, -1.5575],
#         [-0.9406, -1.5575],
#         [-0.6878, -1.3317],
#         [-0.6833, -1.3276],
#         [ 1.3675,  0.5042],
#         [-0.0950,  0.7783],
#         [-0.3018,  0.9647],
#         [-0.1505,  0.7758],
#         [ 1.0173,  0.1914]], grad_fn=<AddBackward0>), tensor([[-1.9140, -2.3069],
#         [-1.9140, -2.3069],
#         [-1.9140, -2.3069],
#         [-1.7814, -2.1528],
#         [-1.7790, -2.1500],
#         [-0.7035, -0.8993],
#         [-1.6955, -2.0599],
#         [-1.8568, -2.2492],
#         [-1.7314, -2.1018],
#         [-0.8872, -1.1129]], grad_fn=<AddBackward0>))
# (tensor([[-0.7001, -1.3427],
#         [-0.9570, -1.5721],
#         [-0.6806, -1.3252],
#         [-0.9570, -1.5721],
#         [-0.9570, -1.5721],
#         [ 1.3675,  0.5042],
#         [-0.0950,  0.7783],
#         [-0.3018,  0.9647],
#         [-0.1505,  0.7758],
#         [ 1.0173,  0.1914]], grad_fn=<AddBackward0>), tensor([[-1.7879, -2.1603],
#         [-1.9226, -2.3169],
#         [-1.7776, -2.1483],
#         [-1.9226, -2.3169],
#         [-1.9226, -2.3169],
#         [-0.7035, -0.8993],
#         [-1.6955, -2.0599],
#         [-1.8568, -2.2492],
#         [-1.7314, -2.1018],
#         [-0.8872, -1.1129]], grad_fn=<AddBackward0>))
# (tensor([[-0.6677, -1.3137],
#         [-1.0280, -1.6356],
#         [-0.3427, -1.0234],
#         [-0.6847, -1.3289],
#         [-1.3615, -1.9334],
#         [ 1.3675,  0.5042],
#         [-0.0950,  0.7783],
#         [-0.3018,  0.9647],
#         [-0.1505,  0.7758],
#         [ 1.0173,  0.1914]], grad_fn=<AddBackward0>), tensor([[-1.7708, -2.1405],
#         [-1.9598, -2.3602],
#         [-1.6004, -1.9423],
#         [-1.7797, -2.1508],
#         [-2.1347, -2.5636],
#         [-0.7035, -0.8993],
#         [-1.6955, -2.0599],
#         [-1.8568, -2.2492],
#         [-1.7314, -2.1018],
#         [-0.8872, -1.1129]], grad_fn=<AddBackward0>))
# (tensor([[-0.8156, -1.4458],
#         [-0.8156, -1.4458],
#         [-1.1944, -1.7841],
#         [-0.8156, -1.4458],
#         [-0.3676, -1.0457],
#         [ 1.3675,  0.5042],
#         [-0.0950,  0.7783],
#         [-0.3018,  0.9647],
#         [-0.1505,  0.7758],
#         [ 1.0173,  0.1914]], grad_fn=<AddBackward0>), tensor([[-1.8484, -2.2307],
#         [-1.8484, -2.2307],
#         [-2.0470, -2.4617],
#         [-1.8484, -2.2307],
#         [-1.6135, -1.9575],
#         [-0.7035, -0.8993],
#         [-1.6955, -2.0599],
#         [-1.8568, -2.2492],
#         [-1.7314, -2.1018],
#         [-0.8872, -1.1129]], grad_fn=<AddBackward0>))
# (tensor([[-0.8492, -1.4758],
#         [-0.8492, -1.4758],
#         [-0.8492, -1.4758],
#         [-0.8492, -1.4758],
#         [-0.8492, -1.4758],
#         [ 1.3675,  0.5042],
#         [-0.0950,  0.7783],
#         [-0.3018,  0.9647],
#         [-0.1505,  0.7758],
#         [ 1.0173,  0.1914]], grad_fn=<AddBackward0>), tensor([[-1.8660, -2.2512],
#         [-1.8660, -2.2512],
#         [-1.8660, -2.2512],
#         [-1.8660, -2.2512],
#         [-1.8660, -2.2512],
#         [-0.7035, -0.8993],
#         [-1.6955, -2.0599],
#         [-1.8568, -2.2492],
#         [-1.7314, -2.1018],
#         [-0.8872, -1.1129]], grad_fn=<AddBackward0>))
# (tensor([[-0.5051, -1.1685],
#         [-1.0914, -1.6922],
#         [-0.9443, -1.5607],
#         [-0.9443, -1.5607],
#         [-0.6328, -1.2826],
#         [ 1.3675,  0.5042],
#         [-0.0950,  0.7783],
#         [-0.3018,  0.9647],
#         [-0.1505,  0.7758],
#         [ 1.0173,  0.1914]], grad_fn=<AddBackward0>), tensor([[-1.6856, -2.0413],
#         [-1.9931, -2.3989],
#         [-1.9159, -2.3092],
#         [-1.9159, -2.3092],
#         [-1.7526, -2.1192],
#         [-0.7035, -0.8993],
#         [-1.6955, -2.0599],
#         [-1.8568, -2.2492],
#         [-1.7314, -2.1018],
#         [-0.8872, -1.1129]], grad_fn=<AddBackward0>))
# (tensor([[-0.8714, -1.4956],
#         [-0.8714, -1.4956],
#         [-0.3170, -1.0004],
#         [-0.8714, -1.4956],
#         [-1.2214, -1.8083],
#         [ 1.3675,  0.5042],
#         [-0.0950,  0.7783],
#         [-0.3018,  0.9647],
#         [-0.1505,  0.7758],
#         [ 1.0173,  0.1914]], grad_fn=<AddBackward0>), tensor([[-1.8777, -2.2647],
#         [-1.8777, -2.2647],
#         [-1.5869, -1.9266],
#         [-1.8777, -2.2647],
#         [-2.0612, -2.4782],
#         [-0.7035, -0.8993],
#         [-1.6955, -2.0599],
#         [-1.8568, -2.2492],
#         [-1.7314, -2.1018],
#         [-0.8872, -1.1129]], grad_fn=<AddBackward0>))
# (tensor([[-1.0595, -1.6637],
#         [-0.7415, -1.3797],
#         [-0.7415, -1.3797],
#         [-0.5386, -1.1984],
#         [-1.0595, -1.6637],
#         [ 1.3675,  0.5042],
#         [-0.0950,  0.7783],
#         [-0.3018,  0.9647],
#         [-0.1505,  0.7758],
#         [ 1.0173,  0.1914]], grad_fn=<AddBackward0>), tensor([[-1.9763, -2.3795],
#         [-1.8096, -2.1855],
#         [-1.8096, -2.1855],
#         [-1.7031, -2.0617],
#         [-1.9763, -2.3795],
#         [-0.7035, -0.8993],
#         [-1.6955, -2.0599],
#         [-1.8568, -2.2492],
#         [-1.7314, -2.1018],
#         [-0.8872, -1.1129]], grad_fn=<AddBackward0>))
# (tensor([[-0.8629, -1.4881],
#         [-0.9267, -1.5450],
#         [-0.5384, -1.1982],
#         [-0.6508, -1.2986],
#         [-1.1936, -1.7835],
#         [ 1.3675,  0.5042],
#         [-0.0950,  0.7783],
#         [-0.3018,  0.9647],
#         [-0.1505,  0.7758],
#         [ 1.0173,  0.1914]], grad_fn=<AddBackward0>), tensor([[-1.8732, -2.2596],
#         [-1.9066, -2.2984],
#         [-1.7030, -2.0616],
#         [-1.7620, -2.1302],
#         [-2.0467, -2.4613],
#         [-0.7035, -0.8993],
#         [-1.6955, -2.0599],
#         [-1.8568, -2.2492],
#         [-1.7314, -2.1018],
#         [-0.8872, -1.1129]], grad_fn=<AddBackward0>))
# (tensor([[-0.6354, -1.2848],
#         [-0.9266, -1.5449],
#         [-0.8929, -1.5148],
#         [-0.8832, -1.5062],
#         [-0.8832, -1.5062],
#         [ 1.3675,  0.5042],
#         [-0.0950,  0.7783],
#         [-0.3018,  0.9647],
#         [-0.1505,  0.7758],
#         [ 1.0173,  0.1914]], grad_fn=<AddBackward0>), tensor([[-1.7539, -2.1208],
#         [-1.9066, -2.2984],
#         [-1.8889, -2.2778],
#         [-1.8839, -2.2719],
#         [-1.8839, -2.2719],
#         [-0.7035, -0.8993],
#         [-1.6955, -2.0599],
#         [-1.8568, -2.2492],
#         [-1.7314, -2.1018],
#         [-0.8872, -1.1129]], grad_fn=<AddBackward0>))
# (tensor([[-1.0524, -1.6573],
#         [-0.8034, -1.4349],
#         [-0.7697, -1.4048],
#         [-0.7988, -1.4308],
#         [-0.7943, -1.4268],
#         [ 1.3675,  0.5042],
#         [-0.0950,  0.7783],
#         [-0.3018,  0.9647],
#         [-0.1505,  0.7758],
#         [ 1.0173,  0.1914]], grad_fn=<AddBackward0>), tensor([[-1.9726, -2.3751],
#         [-1.8420, -2.2232],
#         [-1.8243, -2.2027],
#         [-1.8396, -2.2205],
#         [-1.8372, -2.2177],
#         [-0.7035, -0.8993],
#         [-1.6955, -2.0599],
#         [-1.8568, -2.2492],
#         [-1.7314, -2.1018],
#         [-0.8872, -1.1129]], grad_fn=<AddBackward0>))
# (tensor([[-0.9406, -1.5575],
#         [-0.9406, -1.5575],
#         [-0.9406, -1.5575],
#         [-0.6878, -1.3317],
#         [-0.6833, -1.3276],
#         [ 1.3675,  0.5042],
#         [-0.0950,  0.7783],
#         [-0.3018,  0.9647],
#         [-0.1505,  0.7758],
#         [ 1.0173,  0.1914]], grad_fn=<AddBackward0>), tensor([[-1.9140, -2.3069],
#         [-1.9140, -2.3069],
#         [-1.9140, -2.3069],
#         [-1.7814, -2.1528],
#         [-1.7790, -2.1500],
#         [-0.7035, -0.8993],
#         [-1.6955, -2.0599],
#         [-1.8568, -2.2492],
#         [-1.7314, -2.1018],
#         [-0.8872, -1.1129]], grad_fn=<AddBackward0>))
# (tensor([[-0.9363, -1.5536],
#         [-0.6865, -1.3305],
#         [-0.9363, -1.5536],
#         [-0.6820, -1.3264],
#         [-0.9363, -1.5536],
#         [ 1.3675,  0.5042],
#         [-0.0950,  0.7783],
#         [-0.3018,  0.9647],
#         [-0.1505,  0.7758],
#         [ 1.0173,  0.1914]], grad_fn=<AddBackward0>), tensor([[-1.9117, -2.3043],
#         [-1.7807, -2.1520],
#         [-1.9117, -2.3043],
#         [-1.7783, -2.1492],
#         [-1.9117, -2.3043],
#         [-0.7035, -0.8993],
#         [-1.6955, -2.0599],
#         [-1.8568, -2.2492],
#         [-1.7314, -2.1018],
#         [-0.8872, -1.1129]], grad_fn=<AddBackward0>))
# (tensor([[-0.7001, -1.3427],
#         [-0.9570, -1.5721],
#         [-0.6806, -1.3252],
#         [-0.9570, -1.5721],
#         [-0.9570, -1.5721],
#         [ 1.3675,  0.5042],
#         [-0.0950,  0.7783],
#         [-0.3018,  0.9647],
#         [-0.1505,  0.7758],
#         [ 1.0173,  0.1914]], grad_fn=<AddBackward0>), tensor([[-1.7879, -2.1603],
#         [-1.9226, -2.3169],
#         [-1.7776, -2.1483],
#         [-1.9226, -2.3169],
#         [-1.9226, -2.3169],
#         [-0.7035, -0.8993],
#         [-1.6955, -2.0599],
#         [-1.8568, -2.2492],
#         [-1.7314, -2.1018],
#         [-0.8872, -1.1129]], grad_fn=<AddBackward0>))
# (tensor([[-0.8577, -1.4834],
#         [-0.6000, -1.2532],
#         [-1.1635, -1.7566],
#         [-0.8845, -1.5073],
#         [-0.5569, -1.2148],
#         [ 1.3675,  0.5042],
#         [-0.0950,  0.7783],
#         [-0.3018,  0.9647],
#         [-0.1505,  0.7758],
#         [ 1.0173,  0.1914]], grad_fn=<AddBackward0>), tensor([[-1.8705, -2.2564],
#         [-1.7353, -2.0992],
#         [-2.0309, -2.4429],
#         [-1.8845, -2.2727],
#         [-1.7128, -2.0730],
#         [-0.7035, -0.8993],
#         [-1.6955, -2.0599],
#         [-1.8568, -2.2492],
#         [-1.7314, -2.1018],
#         [-0.8872, -1.1129]], grad_fn=<AddBackward0>))
# (tensor([[-0.7150, -1.3559],
#         [-1.0536, -1.6584],
#         [-0.6889, -1.3326],
#         [-1.0475, -1.6529],
#         [-0.7284, -1.3679],
#         [ 1.3675,  0.5042],
#         [-0.0950,  0.7783],
#         [-0.3018,  0.9647],
#         [-0.1505,  0.7758],
#         [ 1.0173,  0.1914]], grad_fn=<AddBackward0>), tensor([[-1.7956, -2.1693],
#         [-1.9732, -2.3758],
#         [-1.7819, -2.1534],
#         [-1.9700, -2.3721],
#         [-1.8027, -2.1775],
#         [-0.7035, -0.8993],
#         [-1.6955, -2.0599],
#         [-1.8568, -2.2492],
#         [-1.7314, -2.1018],
#         [-0.8872, -1.1129]], grad_fn=<AddBackward0>))
# (tensor([[-0.7950, -1.4274],
#         [-0.8091, -1.4400],
#         [-0.7754, -1.4099],
#         [-1.0566, -1.6611],
#         [-0.8000, -1.4319],
#         [ 1.3675,  0.5042],
#         [-0.0950,  0.7783],
#         [-0.3018,  0.9647],
#         [-0.1505,  0.7758],
#         [ 1.0173,  0.1914]], grad_fn=<AddBackward0>), tensor([[-1.8376, -2.2181],
#         [-1.8450, -2.2267],
#         [-1.8273, -2.2062],
#         [-1.9748, -2.3777],
#         [-1.8402, -2.2212],
#         [-0.7035, -0.8993],
#         [-1.6955, -2.0599],
#         [-1.8568, -2.2492],
#         [-1.7314, -2.1018],
#         [-0.8872, -1.1129]], grad_fn=<AddBackward0>))
# (tensor([[-0.9502, -1.5661],
#         [-0.7052, -1.3472],
#         [-0.6715, -1.3171],
#         [-0.9502, -1.5661],
#         [-0.9502, -1.5661],
#         [ 1.3675,  0.5042],
#         [-0.0950,  0.7783],
#         [-0.3018,  0.9647],
#         [-0.1505,  0.7758],
#         [ 1.0173,  0.1914]], grad_fn=<AddBackward0>), tensor([[-1.9190, -2.3128],
#         [-1.7905, -2.1634],
#         [-1.7728, -2.1428],
#         [-1.9190, -2.3128],
#         [-1.9190, -2.3128],
#         [-0.7035, -0.8993],
#         [-1.6955, -2.0599],
#         [-1.8568, -2.2492],
#         [-1.7314, -2.1018],
#         [-0.8872, -1.1129]], grad_fn=<AddBackward0>))
# (tensor([[-0.6319, -1.2817],
#         [-0.8923, -1.5143],
#         [-0.8898, -1.5121],
#         [-0.8923, -1.5143],
#         [-0.9144, -1.5341],
#         [ 1.3675,  0.5042],
#         [-0.0950,  0.7783],
#         [-0.3018,  0.9647],
#         [-0.1505,  0.7758],
#         [ 1.0173,  0.1914]], grad_fn=<AddBackward0>), tensor([[-1.7521, -2.1187],
#         [-1.8886, -2.2775],
#         [-1.8873, -2.2760],
#         [-1.8886, -2.2775],
#         [-1.9002, -2.2910],
#         [-0.7035, -0.8993],
#         [-1.6955, -2.0599],
#         [-1.8568, -2.2492],
#         [-1.7314, -2.1018],
#         [-0.8872, -1.1129]], grad_fn=<AddBackward0>))
# (tensor([[-0.7001, -1.3427],
#         [-0.9570, -1.5721],
#         [-0.6806, -1.3252],
#         [-0.9570, -1.5721],
#         [-0.9570, -1.5721],
#         [ 1.3675,  0.5042],
#         [-0.0950,  0.7783],
#         [-0.3018,  0.9647],
#         [-0.1505,  0.7758],
#         [ 1.0173,  0.1914]], grad_fn=<AddBackward0>), tensor([[-1.7879, -2.1603],
#         [-1.9226, -2.3169],
#         [-1.7776, -2.1483],
#         [-1.9226, -2.3169],
#         [-1.9226, -2.3169],
#         [-0.7035, -0.8993],
#         [-1.6955, -2.0599],
#         [-1.8568, -2.2492],
#         [-1.7314, -2.1018],
#         [-0.8872, -1.1129]], grad_fn=<AddBackward0>))
# (tensor([[-0.8680, -1.4926],
#         [-0.8799, -1.5032],
#         [-1.1657, -1.7585],
#         [-0.5756, -1.2315],
#         [-0.5833, -1.2384],
#         [ 1.3675,  0.5042],
#         [-0.0950,  0.7783],
#         [-0.3018,  0.9647],
#         [-0.1505,  0.7758],
#         [ 1.0173,  0.1914]], grad_fn=<AddBackward0>), tensor([[-1.8759, -2.2626],
#         [-1.8821, -2.2699],
#         [-2.0320, -2.4442],
#         [-1.7226, -2.0843],
#         [-1.7266, -2.0891],
#         [-0.7035, -0.8993],
#         [-1.6955, -2.0599],
#         [-1.8568, -2.2492],
#         [-1.7314, -2.1018],
#         [-0.8872, -1.1129]], grad_fn=<AddBackward0>))
# (tensor([[-1.1902, -1.7805],
#         [-0.8773, -1.5009],
#         [-0.5543, -1.2124],
#         [-0.6309, -1.2809],
#         [-0.9100, -1.5301],
#         [ 1.3675,  0.5042],
#         [-0.0950,  0.7783],
#         [-0.3018,  0.9647],
#         [-0.1505,  0.7758],
#         [ 1.0173,  0.1914]], grad_fn=<AddBackward0>), tensor([[-2.0449, -2.4592],
#         [-1.8808, -2.2683],
#         [-1.7114, -2.0714],
#         [-1.7516, -2.1181],
#         [-1.8979, -2.2883],
#         [-0.7035, -0.8993],
#         [-1.6955, -2.0599],
#         [-1.8568, -2.2492],
#         [-1.7314, -2.1018],
#         [-0.8872, -1.1129]], grad_fn=<AddBackward0>))
# (tensor([[-0.9210, -1.5400],
#         [-0.5918, -1.2459],
#         [-0.5708, -1.2272],
#         [-1.1169, -1.7149],
#         [-0.9210, -1.5400],
#         [ 1.3675,  0.5042],
#         [-0.0950,  0.7783],
#         [-0.3018,  0.9647],
#         [-0.1505,  0.7758],
#         [ 1.0173,  0.1914]], grad_fn=<AddBackward0>), tensor([[-1.9037, -2.2950],
#         [-1.7310, -2.0942],
#         [-1.7200, -2.0814],
#         [-2.0064, -2.4144],
#         [-1.9037, -2.2950],
#         [-0.7035, -0.8993],
#         [-1.6955, -2.0599],
#         [-1.8568, -2.2492],
#         [-1.7314, -2.1018],
#         [-0.8872, -1.1129]], grad_fn=<AddBackward0>))
# (tensor([[-0.6815, -1.3260],
#         [-0.9430, -1.5597],
#         [-0.9430, -1.5597],
#         [-0.6910, -1.3345],
#         [-0.9430, -1.5597],
#         [ 1.3675,  0.5042],
#         [-0.0950,  0.7783],
#         [-0.3018,  0.9647],
#         [-0.1505,  0.7758],
#         [ 1.0173,  0.1914]], grad_fn=<AddBackward0>), tensor([[-1.7781, -2.1489],
#         [-1.9152, -2.3084],
#         [-1.9152, -2.3084],
#         [-1.7831, -2.1547],
#         [-1.9152, -2.3084],
#         [-0.7035, -0.8993],
#         [-1.6955, -2.0599],
#         [-1.8568, -2.2492],
#         [-1.7314, -2.1018],
#         [-0.8872, -1.1129]], grad_fn=<AddBackward0>))
# (tensor([[-1.0651, -1.6687],
#         [-0.7926, -1.4253],
#         [-0.4784, -1.1447],
#         [-0.7926, -1.4253],
#         [-1.0651, -1.6687],
#         [ 1.3675,  0.5042],
#         [-0.0950,  0.7783],
#         [-0.3018,  0.9647],
#         [-0.1505,  0.7758],
#         [ 1.0173,  0.1914]], grad_fn=<AddBackward0>), tensor([[-1.9792, -2.3828],
#         [-1.8363, -2.2167],
#         [-1.6716, -2.0251],
#         [-1.8363, -2.2167],
#         [-1.9792, -2.3828],
#         [-0.7035, -0.8993],
#         [-1.6955, -2.0599],
#         [-1.8568, -2.2492],
#         [-1.7314, -2.1018],
#         [-0.8872, -1.1129]], grad_fn=<AddBackward0>))
# (tensor([[-0.8492, -1.4758],
#         [-0.8492, -1.4758],
#         [-0.8492, -1.4758],
#         [-0.8492, -1.4758],
#         [-0.8492, -1.4758],
#         [ 1.3675,  0.5042],
#         [-0.0950,  0.7783],
#         [-0.3018,  0.9647],
#         [-0.1505,  0.7758],
#         [ 1.0173,  0.1914]], grad_fn=<AddBackward0>), tensor([[-1.8660, -2.2512],
#         [-1.8660, -2.2512],
#         [-1.8660, -2.2512],
#         [-1.8660, -2.2512],
#         [-1.8660, -2.2512],
#         [-0.7035, -0.8993],
#         [-1.6955, -2.0599],
#         [-1.8568, -2.2492],
#         [-1.7314, -2.1018],
#         [-0.8872, -1.1129]], grad_fn=<AddBackward0>))
# (tensor([[-0.8917, -1.5138],
#         [-0.9407, -1.5576],
#         [-0.6031, -1.2560],
#         [-0.8917, -1.5138],
#         [-0.9317, -1.5495],
#         [ 1.3675,  0.5042],
#         [-0.0950,  0.7783],
#         [-0.3018,  0.9647],
#         [-0.1505,  0.7758],
#         [ 1.0173,  0.1914]], grad_fn=<AddBackward0>), tensor([[-1.8883, -2.2771],
#         [-1.9140, -2.3070],
#         [-1.7370, -2.1011],
#         [-1.8883, -2.2771],
#         [-1.9093, -2.3015],
#         [-0.7035, -0.8993],
#         [-1.6955, -2.0599],
#         [-1.8568, -2.2492],
#         [-1.7314, -2.1018],
#         [-0.8872, -1.1129]], grad_fn=<AddBackward0>))

# %%
# get mu and logstd 

mu_list_in_data = []
logstd_list_in_data = []
for i in range(len(dataset)):
    train_data = dataset[i]
    mu = model.encode(train_data.x, train_data.edge_index)
    mu_list_in_data.append(np.asarray(mu.detach()))

mu_list_reshape = []
n = len(dataset)
for i in range(n):
    mu_list_reshape.append(mu_list_in_data[i].reshape((out_channels * n_node)))

# %%
# input data scatter 
import matplotlib.pyplot as plt
def plot_mu_graph(mu):
    
    n_node = mu.shape[0]
    annotations = [str(i+1) for i in range(n_node)]
    colors = plt.cm.rainbow(np.linspace(0, 1, n_node))
    plt.scatter(mu[:,0],mu[:,1],c=colors, s=100)
    
    for i, label in enumerate(annotations):
        plt.annotate(label, (mu[i,0], mu[i,1]), fontsize=14)

        
plt.subplots(figsize=(20,20))

for graph_i in range(30):
    plt.subplot(5, 6, graph_i+1)
    plot_mu_graph(mu_list_in_data[graph_i])

# %%
# original data mu scatter
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
def plot_scatter_for_mu(mu_list):
    column_names = ["x", "y"]
    mu_for_plot = pd.DataFrame(columns = column_names, data=np.vstack(mu_list))
    mu_for_plot["label"] = list(range(10))*len(mu_list)
    x = mu_for_plot["x"]
    y = mu_for_plot["y"]
    c = mu_for_plot["label"]
    fig, ax = plt.subplots(figsize=(10,10))
    scatter = ax.scatter(x, y, c=c)

    # produce a legend with the unique colors from the scatter
    legend1 = ax.legend(*scatter.legend_elements(),
                        loc="lower left", title="Classes")
    ax.add_artist(legend1)

    plt.grid()
    plt.show()

plot_scatter_for_mu(mu_list_in_data)

# %%
# original adj matrices

import matplotlib.pyplot as plt
fig, ax = plt.subplots(5, 6, figsize=(10,10))
for i in range(30):
    plt.subplot(5, 6, i+1)
    plt.imshow(simu_graph.simu_adj_m()[i], cmap="Greys")

# %%
# original data first 5 vs. last 5
simu_graph = SimuData(n_graph=30)
dataset = simu_graph.graph_dataset()
n_node = simu_graph.n_node

colors = ['#3DAE43', '#67E332','#008000', '#006400', '#228B22',
          '#CD5C5C','#C71585', '#FF4500', '#DB7093', '#FF0000']
mu_list = []
for i in range(len(dataset)):
    train_data = dataset[i]
    mu = model.encode(train_data.x, train_data.edge_index)
    mu_list.append(np.asarray(mu.detach()))

plt.figure(figsize=(10,10))
for node_i in range(n_node):
    
    node_mu = np.empty((0, 2))
    for graph_i in range(len(mu_list)):
    
        node_mu = np.vstack((node_mu, mu_list[graph_i][node_i, :]))
    
    plt.scatter(node_mu[:,0],node_mu[:,1], c=colors[node_i],alpha=0.8)

plt.show()

# %%
# Gaussian distribution for generating mu

import scipy.stats as stats
data_mu = np.zeros((n, out_channels * n_node))
for i in range(n):
    data_mu[i, :] = mu_list_reshape[i]

from sklearn.mixture import GaussianMixture

gm_mu = GaussianMixture(n_components=1, random_state=0).fit(data_mu)
gm_mu.weights_[0] = 1
# Out:
# C:\Users\Ji Qi\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
# got mean and cov for mu generating distribution
means_normal = gm_mu.means_
cov_normal = gm_mu.covariances_
means_normal = np.asarray(means_normal.tolist()[0])
cov_normal = np.asarray(cov_normal.tolist()[0])

# %%
def compute_centrality(mat):
    return (np.sum(mat, axis=0)/mat.shape[0])

# %%
def sample_adj_mat(filter_value=0.75, filter_eye=True):
    model.__mu__ = torch.from_numpy((np.random.multivariate_normal(mean=means_normal,cov=cov_normal)).reshape((n_node,out_channels)))
    z = model.__mu__
    model.decode(z, edge_index)
    adj_mat = np.zeros((n_node, n_node))
    for i in range(n_node*n_node):
        adj_mat[int(edge_index[0, i]), int(edge_index[1, i])] = (model.decode(z, edge_index)[i].detach().numpy()).item()
    adj_mat[adj_mat < filter_value] = 0
    if filter_eye:
        for i in range(adj_mat.shape[0]):
            adj_mat[i,i]=0
    return adj_mat, model.__mu__

# %%
# generate adjacency matrices

generated_from_simu = []
generated_simu_centrality = []

import matplotlib.pyplot as plt
fig, ax = plt.subplots(5, 6, figsize=(20,10))
adj_mat_list = []
mu_list = []
for i in range(30):
    plt.subplot(5, 6, i+1)
    adj_mat, mu_sample = sample_adj_mat(filter_value=0.7)
    generated_from_simu.append(adj_mat)
    generated_simu_centrality.append(compute_centrality(adj_mat))
    adj_mat_list.append(adj_mat)
    mu_list.append(mu_sample.detach().numpy())
    plt.imshow(adj_mat, cmap="Greys")

# %%
plt.subplots(figsize=(20,20))

for graph_i in range(30):
    plt.subplot(5, 6, graph_i+1)
    plot_mu_graph(mu_list[graph_i])

# %%
plot_scatter_for_mu(mu_list)

# %%
simu_adj_list = []
simu_centrality_list = []
for i in range(30):
    adj_mat = simu_graph.simu_adj_m()[i].detach().numpy()
    simu_adj_list.append(adj_mat)
    simu_centrality_list.append(compute_centrality(adj_mat))

# %%
from scipy import stats
res = stats.ttest_ind(generated_simu_centrality, simu_centrality_list, 
                      equal_var=True, axis=0)

display(res)
# Out:
# Ttest_indResult(statistic=array([ 15.56312932,  14.77535086,  15.22146813,  16.30160427,
#         13.75254761,  34.44894362,  84.77932551,  93.16993486,
#        158.86641132,  55.21630421]), pvalue=array([2.27663940e-22, 2.54963240e-21, 6.43099792e-22, 2.53095908e-23,
#        6.58696606e-20, 2.57393683e-40, 1.64972381e-62, 7.19940785e-65,
#        2.94765680e-78, 7.66428733e-52]))

# %%
np.mean(np.vstack(generated_simu_centrality), axis=0)
# Out:
# array([0.37387627, 0.3757858 , 0.36894787, 0.37206782, 0.37507814,
#        0.06360217, 0.02400523, 0.05038571, 0.03571427, 0.05391028])

# %%
np.mean(np.vstack(simu_centrality_list), axis=0)
# Out:
# array([0.21      , 0.24      , 0.19333334, 0.16999997, 0.19333333,
#        0.        , 0.        , 0.        , 0.        , 0.        ],
#       dtype=float32)
